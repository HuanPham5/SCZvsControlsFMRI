# %% [markdown]
# # CNN baseline comparison - y  collapsed-V2

# %%
import nibabel as nib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import numpy as np
import glob
import nibabel as nib
import os
import matplotlib.pyplot as plt
import scipy.ndimage
import random
from tensorflow.keras.layers import Dropout, Dense, Reshape, Flatten, Conv3D, Conv3DTranspose, LeakyReLU, Input, Embedding, multiply, Concatenate
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam, RMSprop
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, Dropout, BatchNormalization
# Out:
# 2024-04-28 18:31:29.671785: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-28 18:31:29.708824: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-28 18:31:29.708858: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-28 18:31:29.709993: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-28 18:31:29.717518: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-28 18:31:30.607629: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def build_3d_cnn(input_shape, num_classes=1):
    model = Sequential([
        Conv3D(64, kernel_size=(10, 10, 10), activation='relu', input_shape=input_shape),
        MaxPooling3D(pool_size=(2, 2, 2)),
        BatchNormalization(),

        Conv3D(128, kernel_size=(5, 5, 5), activation='relu'),
        MaxPooling3D(pool_size=(2, 2, 2)),
        BatchNormalization(),

        Conv3D(128, kernel_size=(3, 3, 3), activation='relu'),
        MaxPooling3D(pool_size=(2, 2, 2)),
        BatchNormalization(),

        Flatten(),

        Dense(5000, activation='relu'),
        Dropout(0.3),  
        Dense(5000, activation='relu'),
        Dropout(0.3),
        Dense(5000, activation='relu'),
        Dropout(0.3),

        Dense(num_classes, activation='sigmoid')
    ])
    
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model


input_shape = (91, 91, 146, 1)
model = build_3d_cnn(input_shape)
model.summary()
# Out:
# 2024-04-28 18:31:52.181440: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46641 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:17:00.0, compute capability: 8.6
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 82, 82, 137, 64)   64064
#
#  max_pooling3d (MaxPooling3  (None, 41, 41, 68, 64)    0
#  D)
#
#  batch_normalization (Batch  (None, 41, 41, 68, 64)    256
#  Normalization)
#
#  conv3d_1 (Conv3D)           (None, 37, 37, 64, 128)   1024128
#
#  max_pooling3d_1 (MaxPoolin  (None, 18, 18, 32, 128)   0
#  g3D)
#
#  batch_normalization_1 (Bat  (None, 18, 18, 32, 128)   512
#  chNormalization)
#
#  conv3d_2 (Conv3D)           (None, 16, 16, 30, 128)   442496
#
#  max_pooling3d_2 (MaxPoolin  (None, 8, 8, 15, 128)     0
#  g3D)
#
#  batch_normalization_2 (Bat  (None, 8, 8, 15, 128)     512
#  chNormalization)
#
#  flatten (Flatten)           (None, 122880)            0
#
#  dense (Dense)               (None, 5000)              614405000
#
#  dropout (Dropout)           (None, 5000)              0
#
#  dense_1 (Dense)             (None, 5000)              25005000
#
#  dropout_1 (Dropout)         (None, 5000)              0
#
#  dense_2 (Dense)             (None, 5000)              25005000
#
#  dropout_2 (Dropout)         (None, 5000)              0
#
#  dense_3 (Dense)             (None, 1)                 5001
#
# =================================================================
# Total params: 665951969 (2.48 GB)
# Trainable params: 665951329 (2.48 GB)
# Non-trainable params: 640 (2.50 KB)
# _________________________________________________________________

# %%
full_schizophrenia_ids = [
    'A00009280', 'A00028806', 'A00023132', 'A00014804', 'A00016859', 'A00021598', 'A00001181', 'A00023158',
    'A00024568', 'A00028405', 'A00001251', 'A00000456', 'A00015648', 'A00002405', 'A00027391', 'A00016720',
    'A00018434', 'A00016197', 'A00027119', 'A00006754', 'A00009656', 'A00038441', 'A00012767', 'A00034273',
    'A00028404', 'A00035485', 'A00024684', 'A00018979', 'A00027537', 'A00004507', 'A00001452', 'A00023246',
    'A00027410', 'A00014719', 'A00024510', 'A00000368', 'A00019293', 'A00014830', 'A00015201', 'A00018403',
    'A00037854', 'A00024198', 'A00001243', 'A00014590', 'A00002337', 'A00024953', 'A00037224', 'A00027616',
    'A00001856', 'A00037619', 'A00024228', 'A00038624', 'A00037034', 'A00037649', 'A00022500', 'A00013216',
    'A00020787', 'A00028410', 'A00002480', 'A00028303', 'A00020602', 'A00024959', 'A00018598', 'A00014636',
    'A00019349', 'A00017147', 'A00023590', 'A00023750', 'A00031597', 'A00015518', 'A00018317', 'A00016723',
    'A00021591', 'A00023243', 'A00017943', 'A00023366', 'A00014607', 'A00020414', 'A00035003', 'A00028805',
    'A00029486', 'A00000541', 'A00028408', 'A00000909', 'A00031186', 'A00000838' ]

# schizohrenia_id that satisfy t>90, 59 in total
met_requirement_schizophrenia_ids = [
    'A00000368', 'A00000456', 'A00000541', 'A00000838', 'A00001251', 'A00001452', 'A00004507',
    'A00006754', 'A00009280', 'A00012767', 'A00013216', 'A00014607', 'A00014719', 'A00014804',
    'A00014830', 'A00015201', 'A00015648', 'A00016197', 'A00016720', 'A00016723', 'A00017147',
    'A00018317', 'A00018403', 'A00018434', 'A00018979', 'A00019293', 'A00020414', 'A00020602', 
    'A00020787', 'A00021591', 'A00021598', 'A00023158', 'A00023246', 'A00023590', 'A00023750', 
    'A00024198', 'A00024228', 'A00024568', 'A00024684', 'A00024953', 'A00024959', 'A00027410', 
    'A00027537', 'A00028303', 'A00028404', 'A00028408', 'A00028805', 'A00028806', 'A00031186', 
    'A00031597', 'A00034273', 'A00035003', 'A00035485', 'A00037034', 'A00037224', 'A00037619', 
    'A00037649', 'A00038441', 'A00038624']

full_control_ids = [
    'A00007409', 'A00013140', 'A00021145', 'A00036049', 'A00022810', 'A00002198', 'A00020895', 'A00004667',
    'A00015826', 'A00023120', 'A00022837', 'A00010684', 'A00009946', 'A00037318', 'A00033214', 'A00022490',
    'A00023848', 'A00029452', 'A00037564', 'A00036555', 'A00023095', 'A00022729', 'A00024955', 'A00024160',
    'A00011725', 'A00027487', 'A00024446', 'A00014898', 'A00015759', 'A00028409', 'A00017294', 'A00014522',
    'A00012995', 'A00031764', 'A00025969', 'A00033147', 'A00018553', 'A00023143', 'A00036916', 'A00028052',
    'A00023337', 'A00023730', 'A00020805', 'A00020984', 'A00000300', 'A00010150', 'A00024932', 'A00035537',
    'A00022509', 'A00028406', 'A00004087', 'A00035751', 'A00023800', 'A00027787', 'A00022687', 'A00023866',
    'A00021085', 'A00022619', 'A00036897', 'A00019888', 'A00021058', 'A00022835', 'A00037495', 'A00026945',
    'A00018716', 'A00026907', 'A00023330', 'A00016199', 'A00037238', 'A00023131', 'A00014120', 'A00021072',
    'A00037665', 'A00022400', 'A00003150', 'A00024372', 'A00021081', 'A00022592', 'A00022653', 'A00013816',
    'A00014839', 'A00031478', 'A00014225', 'A00013363', 'A00037007', 'A00020968', 'A00024301', 'A00024820',
    'A00035469', 'A00029226', 'A00022915', 'A00022773', 'A00024663', 'A00036844', 'A00009207', 'A00024535',
    'A00022727', 'A00011265', 'A00024546'
]

 # 82 controls that met requirement
met_requirement_control_ids = [
    'A00000300', 'A00002198', 'A00003150', 'A00004087', 'A00007409', 'A00010684', 'A00011265', 'A00011725',
    'A00012995', 'A00013140', 'A00013816', 'A00014839', 'A00014898', 'A00015759', 'A00015826', 'A00018553',
    'A00018716', 'A00019888', 'A00020805', 'A00020895', 'A00020968', 'A00020984', 'A00021058', 'A00021072',
    'A00021081', 'A00021085', 'A00022400', 'A00022490', 'A00022509', 'A00022592', 'A00022619', 'A00022653',
    'A00022687', 'A00022727', 'A00022729', 'A00022773', 'A00022810', 'A00022835', 'A00022837', 'A00022915',
    'A00023095', 'A00023120', 'A00023131', 'A00023143', 'A00023330', 'A00023337', 'A00023730', 'A00023800',
    'A00023848', 'A00023866', 'A00024160', 'A00024301', 'A00024372', 'A00024446', 'A00024535', 'A00024546', 
    'A00024663', 'A00024820', 'A00024932', 'A00024955', 'A00025969', 'A00026945', 'A00027487', 'A00027787', 
    'A00028052', 'A00028406', 'A00028409', 'A00029226', 'A00029452', 'A00031478', 'A00031764', 'A00033214', 
    'A00035751', 'A00036049', 'A00036555', 'A00036844', 'A00037007', 'A00037238', 'A00037318', 'A00037495', 
    'A00037564', 'A00037665'
]

# %%
# GAN Training Data Selection
gan_train_ids_schiz = random.sample(met_requirement_schizophrenia_ids, 50)
gan_test_ids_schiz = [id for id in met_requirement_schizophrenia_ids if id not in gan_train_ids_schiz]

gan_train_ids_control = random.sample(met_requirement_control_ids, 50)
gan_test_ids_control = [id for id in met_requirement_control_ids if id not in gan_train_ids_control]
gan_test_ids_control = random.sample(gan_test_ids_control,9)

''' data training for classifier '''
''' just use the same train set as GAN above '''

# Classifier Training Data Selection
#classifier_train_ids = gan_train_ids_control + gan_train_ids_schiz

# Classifier Test Data Selection
classifier_test_ids = gan_test_ids_schiz + gan_test_ids_control

''' File loading '''
# Specify the directory and file pattern
directory_path = '../4D/'
file_pattern = 'A*_????_func_FL_FD_RPI_DSP_MCF_SS_SM_Nui_CS_InStandard.nii.gz'

# Construct the full path pattern
path_pattern = f'{directory_path}/{file_pattern}'

# Use glob to find all matching files
matching_files = glob.glob(path_pattern)

''' File loading for GAN Training and classifer '''
''' But this time we have 2 separate GANs, 1 train on schizoprenia and 1 train on control'''

#classifier_image_data = []
#classifier_labels = []  # 1 for schizophrenia, 0 for non-schizophrenia
gan_image_data_schiz = []
gan_image_data_control = []

for file_path in matching_files:
    filename = os.path.basename(file_path)
    file_id = filename.split('_')[0]
    
    if file_id in gan_train_ids_schiz:
        t1_img = nib.load(file_path)
        t1_data = t1_img.get_fdata()

        if t1_data.shape[3] < 90:
            continue

        t1_data_collapsed = np.sum(t1_data, axis=1)
        gan_image_data_schiz.append(t1_data_collapsed)

    if file_id in gan_train_ids_control:
        t1_img = nib.load(file_path)
        t1_data = t1_img.get_fdata()

        if t1_data.shape[3] < 90:
            continue

        t1_data_collapsed = np.sum(t1_data, axis=1)
        gan_image_data_control.append(t1_data_collapsed)

    # if file_id in classifier_train_ids or file_id in classifier_test_ids:
    #     t1_img = nib.load(file_path)
    #     t1_data = t1_img.get_fdata()

    #     if t1_data.shape[3] < 90:
    #         continue

    #     label = 1 if file_id in met_requirement_schizophrenia_ids else 0
    #     t1_data_collapsed = np.sum(t1_data, axis=1)

    #     classifier_image_data.append(t1_data_collapsed)
    #     classifier_labels.append(label)

print(f"Total GAN control loaded: {len(gan_image_data_control)}")
print(f"Total GAN schiz loaded: {len(gan_image_data_schiz)}")
#print(f"Total classifier training/testing files processed: {len(classifier_image_data)}")
#print(f"Total labels processed: {len(classifier_labels)}")


'''Determine the maximum 3rd-dimension size '''
max_z_size_schiz = max(img.shape[2] for img in gan_image_data_schiz)
max_z_size_control = max(img.shape[2] for img in gan_image_data_control)
#max_z_size_classifier = max(img.shape[2] for img in classifier_image_data)
max_z_size = max(max_z_size_schiz,max_z_size_control)

''' normalization '''
image_data_normalized_schiz = [(img - np.min(img)) / (np.max(img) - np.min(img)) * 2 - 1 for img in gan_image_data_schiz]
image_data_normalized_control = [(img - np.min(img)) / (np.max(img) - np.min(img)) * 2 - 1 for img in gan_image_data_control]
#image_data_normalized_classifier = [(img - np.min(img)) / (np.max(img) - np.min(img)) * 2 - 1 for img in classifier_image_data]

''' padding of images data '''
# Pad each image to have a consistent z-dimension size
padded_data_schiz = [np.pad(img, ((0, 0), (0, 0), (0, max_z_size - img.shape[2])), mode='constant') for img in image_data_normalized_schiz]
padded_data_control = [np.pad(img, ((0, 0), (0, 0), (0, max_z_size - img.shape[2])), mode='constant') for img in image_data_normalized_control]
#padded_data_classifier = [np.pad(img, ((0, 0), (0, 0), (0, max_z_size_classifier - img.shape[2])), mode='constant') for img in image_data_normalized_classifier]

# Now convert the padded data list to a numpy array
padded_data_array_schiz = np.array(padded_data_schiz)
padded_data_array_control = np.array(padded_data_control)
#padded_data_array_classifier = np.array(padded_data_classifier)

''' loading the data for WGAN training '''
train_images_schiz = padded_data_array_schiz
train_images_control = padded_data_array_control

# Define batch size
batch_size = 10


train_dataset_schiz = tf.data.Dataset.from_tensor_slices((train_images_schiz)).shuffle(len(train_images_schiz)).batch(batch_size)
train_dataset_control = tf.data.Dataset.from_tensor_slices((train_images_control)).shuffle(len(train_images_control)).batch(batch_size)

''' setting up parameters'''
# Image shape and other parameters
#img_shape = (84, 84, 72, 1)
#z_dim = 100
# Out:
# Total GAN control loaded: 4
# Total GAN schiz loaded: 4
# ' setting up parameters'

# %%
print(max_z_size_control)

# %%
print(max_z_size_schiz)

# %%
import numpy as np
import tensorflow as tf

# Create labels for the datasets
labels_schiz = np.ones(len(padded_data_array_schiz))  # 1 for schizophrenia
labels_control = np.zeros(len(padded_data_array_control))  # 0 for control

# Combine the data and labels
combined_images = np.concatenate([padded_data_array_schiz, padded_data_array_control], axis=0)
combined_labels = np.concatenate([labels_schiz, labels_control], axis=0)

# Shuffle the combined dataset to ensure the data is randomly distributed
# It's important for training a model that generalizes well
indices = np.arange(combined_images.shape[0])
np.random.shuffle(indices)
shuffled_images = combined_images[indices]
shuffled_labels = combined_labels[indices]

# Convert to TensorFlow Dataset, manually split 80/20
dataset = tf.data.Dataset.from_tensor_slices((shuffled_images, shuffled_labels))
train_size = int(0.8 * len(shuffled_images))
train_dataset = dataset.take(train_size).shuffle(buffer_size=train_size).batch(10)
test_dataset = dataset.skip(train_size).batch(10)

# Model initialization
#input_shape = shuffled_images.shape[1:]  # This includes the channel dimension if already added
#print(input_shape)
#input_shape = (91, 91, 146, 1)
#model = build_3d_cnn(input_shape=input_shape, num_classes=1)

# Train the model
history = model.fit(
    train_dataset,
    epochs=200,
    validation_data=test_dataset
)

# Evaluate the model
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc}, Test loss: {test_loss}")
# Out:
# Epoch 1/1000
# 2024-04-28 18:33:53.933267: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-04-28 18:34:06.426993: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f7a3148b850 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-04-28 18:34:06.427033: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-04-28 18:34:06.432303: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714329246.531691  241402 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 [==============================] - 25s 25s/step - loss: 0.6498 - accuracy: 0.6667 - val_loss: 4.4035 - val_accuracy: 0.5000
# Epoch 2/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 20.4575 - accuracy: 0.5000 - val_loss: 74.6377 - val_accuracy: 0.5000
# Epoch 3/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 484.9240 - accuracy: 0.5000 - val_loss: 182.0512 - val_accuracy: 0.5000
# Epoch 4/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 1025.6256 - accuracy: 0.5000 - val_loss: 140.2797 - val_accuracy: 0.5000
# Epoch 5/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 305.0379 - accuracy: 0.5000 - val_loss: 17.6818 - val_accuracy: 0.5000
# Epoch 6/1000
# 1/1 [==============================] - 0s 397ms/step - loss: 37.5930 - accuracy: 0.6667 - val_loss: 82.7444 - val_accuracy: 0.5000
# Epoch 7/1000
# 1/1 [==============================] - 0s 399ms/step - loss: 15.5715 - accuracy: 0.8333 - val_loss: 43.6749 - val_accuracy: 0.5000
# Epoch 8/1000
# 1/1 [==============================] - 0s 400ms/step - loss: 35.6654 - accuracy: 0.5000 - val_loss: 448.3795 - val_accuracy: 0.5000
# Epoch 9/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 33.3404 - accuracy: 0.8333 - val_loss: 93.7828 - val_accuracy: 0.5000
# Epoch 10/1000
# 1/1 [==============================] - 0s 393ms/step - loss: 4.0780e-19 - accuracy: 1.0000 - val_loss: 285.8067 - val_accuracy: 0.5000
# Epoch 11/1000
# 1/1 [==============================] - 0s 400ms/step - loss: 7.6765 - accuracy: 0.8333 - val_loss: 567.5901 - val_accuracy: 0.5000
# Epoch 12/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 833.5695 - val_accuracy: 0.5000
# Epoch 13/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 1.4991e-14 - accuracy: 1.0000 - val_loss: 1077.4171 - val_accuracy: 0.5000
# Epoch 14/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1295.9020 - val_accuracy: 0.5000
# Epoch 15/1000
# 1/1 [==============================] - 0s 395ms/step - loss: 1.8236e-15 - accuracy: 1.0000 - val_loss: 1485.1202 - val_accuracy: 0.5000
# Epoch 16/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 54.7368 - accuracy: 0.8333 - val_loss: 1168.1925 - val_accuracy: 0.5000
# Epoch 17/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 895.8082 - val_accuracy: 0.5000
# Epoch 18/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 119.9937 - accuracy: 0.8333 - val_loss: 1318.2694 - val_accuracy: 0.5000
# Epoch 19/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 2.2852e-25 - accuracy: 1.0000 - val_loss: 1681.1268 - val_accuracy: 0.5000
# Epoch 20/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1983.1814 - val_accuracy: 0.5000
# Epoch 21/1000
# 1/1 [==============================] - 0s 375ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2226.1492 - val_accuracy: 0.5000
# Epoch 22/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2414.8733 - val_accuracy: 0.5000
# Epoch 23/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2560.7258 - val_accuracy: 0.5000
# Epoch 24/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2665.1555 - val_accuracy: 0.5000
# Epoch 25/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2734.5217 - val_accuracy: 0.5000
# Epoch 26/1000
# 1/1 [==============================] - 0s 400ms/step - loss: 6.3287e-23 - accuracy: 1.0000 - val_loss: 2773.2380 - val_accuracy: 0.5000
# Epoch 27/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2785.5598 - val_accuracy: 0.5000
# Epoch 28/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 13.3843 - accuracy: 0.8333 - val_loss: 2714.6047 - val_accuracy: 0.5000
# Epoch 29/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2618.8235 - val_accuracy: 0.5000
# Epoch 30/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2501.7917 - val_accuracy: 0.5000
# Epoch 31/1000
# 1/1 [==============================] - 0s 393ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2368.1731 - val_accuracy: 0.5000
# Epoch 32/1000
# 1/1 [==============================] - 0s 397ms/step - loss: 51.5864 - accuracy: 0.8333 - val_loss: 3663.9592 - val_accuracy: 0.5000
# Epoch 33/1000
# 1/1 [==============================] - 0s 399ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4588.2056 - val_accuracy: 0.5000
# Epoch 34/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5303.6201 - val_accuracy: 0.5000
# Epoch 35/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 1.6165e-36 - accuracy: 1.0000 - val_loss: 5875.9463 - val_accuracy: 0.5000
# Epoch 36/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 479.8104 - accuracy: 0.5000 - val_loss: 2196.4460 - val_accuracy: 0.5000
# Epoch 37/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 38/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 39/1000
# 1/1 [==============================] - 0s 391ms/step - loss: 47.3793 - accuracy: 0.8333 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 40/1000
# 1/1 [==============================] - 0s 398ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 41/1000
# 1/1 [==============================] - 0s 396ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 42/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 43/1000
# 1/1 [==============================] - 0s 398ms/step - loss: 88.2354 - accuracy: 0.8333 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 44/1000
# 1/1 [==============================] - 0s 398ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 45/1000
# 1/1 [==============================] - 0s 396ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 46/1000
# 1/1 [==============================] - 0s 397ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 47/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 48/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 49/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 50/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 51/1000
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 52/1000
# 1/1 [==============================] - 0s 396ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 53/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 54/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 55/1000
# 1/1 [==============================] - 0s 400ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 56/1000
# 1/1 [==============================] - 0s 398ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 57/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 58/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 59/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 60/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 61/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 62/1000
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 63/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 64/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 65/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 66/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 67/1000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 68/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 69/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 70/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 71/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 72/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 73/1000
# 1/1 [==============================] - 0s 377ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 74/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 75/1000
# 1/1 [==============================] - 0s 397ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 76/1000
# 1/1 [==============================] - 0s 398ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 77/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 78/1000
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 79/1000
# 1/1 [==============================] - 0s 404ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 80/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 81/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 82/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 83/1000
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 84/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 85/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 86/1000
# 1/1 [==============================] - 0s 399ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 87/1000
# 1/1 [==============================] - 0s 404ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 88/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 89/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 90/1000
# 1/1 [==============================] - 0s 399ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 91/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 92/1000
# 1/1 [==============================] - 0s 394ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 93/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 94/1000
# 1/1 [==============================] - 0s 401ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 95/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 96/1000
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 97/1000
# 1/1 [==============================] - 0s 401ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 98/1000
# 1/1 [==============================] - 0s 406ms/step - loss: 152.3950 - accuracy: 0.8333 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 99/1000
# 1/1 [==============================] - 0s 401ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 100/1000
# 1/1 [==============================] - 0s 391ms/step - loss: 930.2993 - accuracy: 0.8333 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 101/1000
# 1/1 [==============================] - 0s 400ms/step - loss: 125.4037 - accuracy: 0.8333 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 102/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 103/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 104/1000
# 1/1 [==============================] - 0s 398ms/step - loss: 425.6333 - accuracy: 0.8333 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 105/1000
# 1/1 [==============================] - 0s 398ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 106/1000
# 1/1 [==============================] - 0s 403ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 107/1000
# 1/1 [==============================] - 0s 400ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 108/1000
# 1/1 [==============================] - 0s 400ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 109/1000
# 1/1 [==============================] - 0s 404ms/step - loss: 65.5303 - accuracy: 0.8333 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 110/1000
# 1/1 [==============================] - 0s 395ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 111/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 112/1000
# 1/1 [==============================] - 0s 393ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 113/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 114/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 115/1000
# 1/1 [==============================] - 0s 394ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 116/1000
# 1/1 [==============================] - 0s 403ms/step - loss: 282.0196 - accuracy: 0.8333 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 117/1000
# 1/1 [==============================] - 0s 403ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 118/1000
# 1/1 [==============================] - 0s 401ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 119/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 120/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 121/1000
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 122/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 123/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 124/1000
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 125/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 126/1000
# 1/1 [==============================] - 0s 404ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 127/1000
# 1/1 [==============================] - 0s 403ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 128/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 129/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 130/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 131/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 132/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 133/1000
# 1/1 [==============================] - 0s 397ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 134/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 135/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 136/1000
# 1/1 [==============================] - 0s 398ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 137/1000
# 1/1 [==============================] - 0s 398ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 138/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 139/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 140/1000
# 1/1 [==============================] - 0s 394ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 141/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 142/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 143/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 144/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 145/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 146/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 147/1000
# 1/1 [==============================] - 0s 395ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 148/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 149/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 150/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 151/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 152/1000
# 1/1 [==============================] - 0s 401ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 153/1000
# 1/1 [==============================] - 0s 406ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 154/1000
# 1/1 [==============================] - 0s 402ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 155/1000
# 1/1 [==============================] - 0s 395ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 156/1000
# 1/1 [==============================] - 0s 393ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 157/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 158/1000
# 1/1 [==============================] - 0s 396ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 159/1000
# 1/1 [==============================] - 0s 407ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 160/1000
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 161/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 162/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 163/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 164/1000
# 1/1 [==============================] - 0s 397ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 165/1000
# 1/1 [==============================] - 0s 395ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 166/1000
# 1/1 [==============================] - 0s 397ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 167/1000
# 1/1 [==============================] - 0s 400ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 168/1000
# 1/1 [==============================] - 0s 393ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 169/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 170/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 171/1000
# 1/1 [==============================] - 0s 380ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 172/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 173/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 174/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 175/1000
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 176/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 177/1000
# 1/1 [==============================] - 0s 396ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 178/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 179/1000
# 1/1 [==============================] - 0s 395ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 180/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 181/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 182/1000
# 1/1 [==============================] - 0s 393ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 183/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 184/1000
# 1/1 [==============================] - 0s 393ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 185/1000
# 1/1 [==============================] - 0s 399ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 186/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 187/1000
# 1/1 [==============================] - 0s 399ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 188/1000
# 1/1 [==============================] - 0s 400ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 189/1000
# 1/1 [==============================] - 0s 400ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 190/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 191/1000
# 1/1 [==============================] - 0s 394ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 192/1000
# 1/1 [==============================] - 0s 400ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 193/1000
# 1/1 [==============================] - 0s 394ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 194/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 195/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 196/1000
# 1/1 [==============================] - 0s 397ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 197/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 198/1000
# 1/1 [==============================] - 0s 398ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 199/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 200/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 201/1000
# 1/1 [==============================] - 0s 395ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 202/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 203/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 204/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 205/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 206/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 207/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 208/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 209/1000
# 1/1 [==============================] - 0s 395ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 210/1000
# 1/1 [==============================] - 0s 393ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 211/1000
# 1/1 [==============================] - 0s 399ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 212/1000
# 1/1 [==============================] - 0s 403ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 213/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 214/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 215/1000
# 1/1 [==============================] - 0s 402ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 216/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 217/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 218/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 219/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 220/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 221/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 222/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 223/1000
# 1/1 [==============================] - 0s 381ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 224/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 225/1000
# 1/1 [==============================] - 0s 394ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 226/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 227/1000
# 1/1 [==============================] - 0s 394ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 228/1000
# 1/1 [==============================] - 0s 404ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 229/1000
# 1/1 [==============================] - 0s 404ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 230/1000
# 1/1 [==============================] - 0s 402ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 231/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 232/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 233/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 234/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 235/1000
# 1/1 [==============================] - 0s 393ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 236/1000
# 1/1 [==============================] - 0s 402ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 237/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 238/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 239/1000
# 1/1 [==============================] - 0s 396ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 240/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 241/1000
# 1/1 [==============================] - 0s 403ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 242/1000
# 1/1 [==============================] - 0s 403ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 243/1000
# 1/1 [==============================] - 0s 406ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 244/1000
# 1/1 [==============================] - 0s 407ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 245/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 246/1000
# 1/1 [==============================] - 0s 396ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 247/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 248/1000
# 1/1 [==============================] - 0s 396ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 249/1000
# 1/1 [==============================] - 0s 404ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 250/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 251/1000
# 1/1 [==============================] - 0s 404ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 252/1000
# 1/1 [==============================] - 0s 396ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 253/1000
# 1/1 [==============================] - 0s 398ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 254/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 255/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 256/1000
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 257/1000
# 1/1 [==============================] - 0s 398ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 258/1000
# 1/1 [==============================] - 0s 406ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 259/1000
# 1/1 [==============================] - 0s 404ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 260/1000
# 1/1 [==============================] - 0s 395ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 261/1000
# 1/1 [==============================] - 0s 401ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 262/1000
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 263/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 264/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 265/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 266/1000
# 1/1 [==============================] - 0s 401ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 267/1000
# 1/1 [==============================] - 0s 404ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 268/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 269/1000
# 1/1 [==============================] - 0s 403ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 270/1000
# 1/1 [==============================] - 0s 395ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 271/1000
# 1/1 [==============================] - 0s 397ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 272/1000
# 1/1 [==============================] - 0s 394ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 273/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 274/1000
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 275/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 276/1000
# 1/1 [==============================] - 0s 387ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 277/1000
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 278/1000
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 279/1000
# 1/1 [==============================] - 0s 388ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 280/1000
# 1/1 [==============================] - 0s 402ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 281/1000
# 1/1 [==============================] - 0s 393ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 282/1000
# 1/1 [==============================] - 0s 389ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 283/1000
# 1/1 [==============================] - 0s 402ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 284/1000
# 1/1 [==============================] - 0s 406ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 285/1000
# 1/1 [==============================] - 0s 406ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 286/1000
# 1/1 [==============================] - 0s 407ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 287/1000
# 1/1 [==============================] - 0s 404ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 288/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 289/1000
# 1/1 [==============================] - 0s 393ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 290/1000
# 1/1 [==============================] - 0s 401ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 291/1000
# 1/1 [==============================] - 0s 402ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 292/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 293/1000
# 1/1 [==============================] - 0s 406ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 294/1000
# 1/1 [==============================] - 0s 394ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 295/1000
# 1/1 [==============================] - 0s 385ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 296/1000
# 1/1 [==============================] - 0s 400ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 297/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 298/1000
# 1/1 [==============================] - 0s 393ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 299/1000
# 1/1 [==============================] - 0s 386ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 300/1000
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 301/1000
# 1/1 [==============================] - 0s 396ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 302/1000
# 1/1 [==============================] - 0s 392ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 303/1000
# 1/1 [==============================] - 0s 403ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 304/1000
# 1/1 [==============================] - 0s 408ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 305/1000
# 1/1 [==============================] - 0s 394ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 306/1000
# 1/1 [==============================] - 0s 402ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 307/1000
# 1/1 [==============================] - 0s 405ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 308/1000
# 1/1 [==============================] - 0s 401ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 309/1000
# 1/1 [==============================] - 0s 394ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 310/1000
# 1/1 [==============================] - 0s 397ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 311/1000
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 312/1000
# ...
# Epoch 897/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 898/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 899/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 900/1000
# 1/1 [==============================] - 0s 415ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 901/1000
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 902/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 903/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 904/1000
# 1/1 [==============================] - 0s 408ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 905/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 906/1000
# 1/1 [==============================] - 0s 409ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 907/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 908/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 909/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 910/1000
# 1/1 [==============================] - 0s 408ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 911/1000
# 1/1 [==============================] - 0s 417ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 912/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 913/1000
# 1/1 [==============================] - 0s 416ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 914/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 915/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 916/1000
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 917/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 918/1000
# 1/1 [==============================] - 0s 415ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 919/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 920/1000
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 921/1000
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 922/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 923/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 924/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 925/1000
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 926/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 927/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 928/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 929/1000
# 1/1 [==============================] - 0s 409ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 930/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 931/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 932/1000
# 1/1 [==============================] - 0s 415ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 933/1000
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 934/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 935/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 936/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 937/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 938/1000
# 1/1 [==============================] - 0s 415ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 939/1000
# 1/1 [==============================] - 0s 409ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 940/1000
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 941/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 942/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 943/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 944/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 945/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 946/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 947/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 948/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 949/1000
# 1/1 [==============================] - 0s 419ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 950/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 951/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 952/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 953/1000
# 1/1 [==============================] - 0s 408ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 954/1000
# 1/1 [==============================] - 0s 418ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 955/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 956/1000
# 1/1 [==============================] - 0s 415ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 957/1000
# 1/1 [==============================] - 0s 418ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 958/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 959/1000
# 1/1 [==============================] - 0s 415ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 960/1000
# 1/1 [==============================] - 0s 408ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 961/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 962/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 963/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 964/1000
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 965/1000
# 1/1 [==============================] - 0s 408ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 966/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 967/1000
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 968/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 969/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 970/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 971/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 972/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 973/1000
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 974/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 975/1000
# 1/1 [==============================] - 0s 407ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 976/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 977/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 978/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 979/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 980/1000
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 981/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 982/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 983/1000
# 1/1 [==============================] - 0s 415ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 984/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 985/1000
# 1/1 [==============================] - 0s 409ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 986/1000
# 1/1 [==============================] - 0s 409ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 987/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 988/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 989/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 990/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 991/1000
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 992/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 993/1000
# 1/1 [==============================] - 0s 417ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 994/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 995/1000
# 1/1 [==============================] - 0s 415ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 996/1000
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 997/1000
# 1/1 [==============================] - 0s 408ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 998/1000
# 1/1 [==============================] - 0s 408ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 999/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 1000/1000
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Test accuracy: 1.0, Test loss: 0.0

# %%
def resize_image(image, new_shape):
    factors = (
        new_shape[0]/image.shape[0],
        new_shape[1]/image.shape[1],
        new_shape[2]/image.shape[2]
    )
    return scipy.ndimage.zoom(image, factors, order=1)  # order=1 is bilinear interpolation

''' load test images to make test set'''
# Now proceed with loading and preprocessing the images for these IDs
test_image_data = []
test_labels = []

test_ids = classifier_test_ids

# Loop through the matching files and filter based on test IDs
for file_path in matching_files:
    filename = os.path.basename(file_path)
    file_id = filename.split('_')[0]

    # Process only if the ID is in the test set
    if file_id in test_ids:
        t1_img = nib.load(file_path)
        t1_data = t1_img.get_fdata()

        # Ensure sufficient time dimension
        if t1_data.shape[3] < 90:
            continue

        # Collapse one of the axes by summing
        t1_data_collapsed = np.sum(t1_data, axis=1)

        # Resize, normalize, and add dimension as done in the training data preparation
        processed_image = resize_image(t1_data_collapsed, (91, 91, 146))
        processed_image_normalized = (processed_image - np.min(processed_image)) / (np.max(processed_image) - np.min(processed_image)) * 2 - 1
        processed_image_final = np.expand_dims(processed_image_normalized, axis=-1)

        test_image_data.append(processed_image_final)
        label = 1 if file_id in met_requirement_schizophrenia_ids else 0
        test_labels.append(label)

# Convert to numpy arrays
test_images_array = np.array(test_image_data)
test_labels_array = np.array(test_labels)


test_dataset = tf.data.Dataset.from_tensor_slices((test_images_array, test_labels_array)).batch(batch_size)

loss, accuracy = model.evaluate(test_dataset)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 6/6 [==============================] - 36s 3s/step - loss: 18343.0898 - accuracy: 0.3390
# Test Loss: 18343.08984375
# Test Accuracy: 0.33898305892944336
