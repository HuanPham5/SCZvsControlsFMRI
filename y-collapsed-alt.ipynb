# %% [markdown]
# # WGAN version v3 training + testing all in one file
#
# ## only schizophrenia
#
# ### pick only 50 random schizophrenia for training GAN, leave 9 untouch for testing
#
# ### When training 2nd time for classification, also pick 50 random control, leave 9 untouch for testing

# %%
import nibabel as nib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import numpy as np
import glob
import nibabel as nib
import os
import matplotlib.pyplot as plt
import scipy.ndimage
import random
from tensorflow.keras.layers import Dropout, Dense, Reshape, Flatten, Conv3D, Conv3DTranspose, LeakyReLU, Input, Embedding, multiply, Concatenate
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam, RMSprop
from sklearn.model_selection import train_test_split
# Out:
# 2024-01-31 03:27:36.194265: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-31 03:27:36.232667: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-31 03:27:36.232695: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-31 03:27:36.233811: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-31 03:27:36.240913: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-31 03:27:37.032121: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# List all physical devices of type 'GPU'
gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
    print(f'Number of GPUs available: {len(gpus)}')
    for i, gpu in enumerate(gpus):
        print(f'GPU {i}: {gpu}')
else:
    print('No GPU detected.')
# Out:
# Number of GPUs available: 1
# GPU 0: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
# full list of all schizophrenia IDs from csv, 86 in total but not all satisfy have t>90

full_schizophrenia_ids = [
    'A00009280', 'A00028806', 'A00023132', 'A00014804', 'A00016859', 'A00021598', 'A00001181', 'A00023158',
    'A00024568', 'A00028405', 'A00001251', 'A00000456', 'A00015648', 'A00002405', 'A00027391', 'A00016720',
    'A00018434', 'A00016197', 'A00027119', 'A00006754', 'A00009656', 'A00038441', 'A00012767', 'A00034273',
    'A00028404', 'A00035485', 'A00024684', 'A00018979', 'A00027537', 'A00004507', 'A00001452', 'A00023246',
    'A00027410', 'A00014719', 'A00024510', 'A00000368', 'A00019293', 'A00014830', 'A00015201', 'A00018403',
    'A00037854', 'A00024198', 'A00001243', 'A00014590', 'A00002337', 'A00024953', 'A00037224', 'A00027616',
    'A00001856', 'A00037619', 'A00024228', 'A00038624', 'A00037034', 'A00037649', 'A00022500', 'A00013216',
    'A00020787', 'A00028410', 'A00002480', 'A00028303', 'A00020602', 'A00024959', 'A00018598', 'A00014636',
    'A00019349', 'A00017147', 'A00023590', 'A00023750', 'A00031597', 'A00015518', 'A00018317', 'A00016723',
    'A00021591', 'A00023243', 'A00017943', 'A00023366', 'A00014607', 'A00020414', 'A00035003', 'A00028805',
    'A00029486', 'A00000541', 'A00028408', 'A00000909', 'A00031186', 'A00000838' ]

# schizohrenia_id that satisfy t>90, 59 in total
met_requirement_schizophrenia_ids = [
    'A00000368', 'A00000456', 'A00000541', 'A00000838', 'A00001251', 'A00001452', 'A00004507',
    'A00006754', 'A00009280', 'A00012767', 'A00013216', 'A00014607', 'A00014719', 'A00014804',
    'A00014830', 'A00015201', 'A00015648', 'A00016197', 'A00016720', 'A00016723', 'A00017147',
    'A00018317', 'A00018403', 'A00018434', 'A00018979', 'A00019293', 'A00020414', 'A00020602', 
    'A00020787', 'A00021591', 'A00021598', 'A00023158', 'A00023246', 'A00023590', 'A00023750', 
    'A00024198', 'A00024228', 'A00024568', 'A00024684', 'A00024953', 'A00024959', 'A00027410', 
    'A00027537', 'A00028303', 'A00028404', 'A00028408', 'A00028805', 'A00028806', 'A00031186', 
    'A00031597', 'A00034273', 'A00035003', 'A00035485', 'A00037034', 'A00037224', 'A00037619', 
    'A00037649', 'A00038441', 'A00038624']

full_control_ids = [
    'A00007409', 'A00013140', 'A00021145', 'A00036049', 'A00022810', 'A00002198', 'A00020895', 'A00004667',
    'A00015826', 'A00023120', 'A00022837', 'A00010684', 'A00009946', 'A00037318', 'A00033214', 'A00022490',
    'A00023848', 'A00029452', 'A00037564', 'A00036555', 'A00023095', 'A00022729', 'A00024955', 'A00024160',
    'A00011725', 'A00027487', 'A00024446', 'A00014898', 'A00015759', 'A00028409', 'A00017294', 'A00014522',
    'A00012995', 'A00031764', 'A00025969', 'A00033147', 'A00018553', 'A00023143', 'A00036916', 'A00028052',
    'A00023337', 'A00023730', 'A00020805', 'A00020984', 'A00000300', 'A00010150', 'A00024932', 'A00035537',
    'A00022509', 'A00028406', 'A00004087', 'A00035751', 'A00023800', 'A00027787', 'A00022687', 'A00023866',
    'A00021085', 'A00022619', 'A00036897', 'A00019888', 'A00021058', 'A00022835', 'A00037495', 'A00026945',
    'A00018716', 'A00026907', 'A00023330', 'A00016199', 'A00037238', 'A00023131', 'A00014120', 'A00021072',
    'A00037665', 'A00022400', 'A00003150', 'A00024372', 'A00021081', 'A00022592', 'A00022653', 'A00013816',
    'A00014839', 'A00031478', 'A00014225', 'A00013363', 'A00037007', 'A00020968', 'A00024301', 'A00024820',
    'A00035469', 'A00029226', 'A00022915', 'A00022773', 'A00024663', 'A00036844', 'A00009207', 'A00024535',
    'A00022727', 'A00011265', 'A00024546'
]

 # 82 controls that met requirement
met_requirement_control_ids = [
    'A00000300', 'A00002198', 'A00003150', 'A00004087', 'A00007409', 'A00010684', 'A00011265', 'A00011725',
    'A00012995', 'A00013140', 'A00013816', 'A00014839', 'A00014898', 'A00015759', 'A00015826', 'A00018553',
    'A00018716', 'A00019888', 'A00020805', 'A00020895', 'A00020968', 'A00020984', 'A00021058', 'A00021072',
    'A00021081', 'A00021085', 'A00022400', 'A00022490', 'A00022509', 'A00022592', 'A00022619', 'A00022653',
    'A00022687', 'A00022727', 'A00022729', 'A00022773', 'A00022810', 'A00022835', 'A00022837', 'A00022915',
    'A00023095', 'A00023120', 'A00023131', 'A00023143', 'A00023330', 'A00023337', 'A00023730', 'A00023800',
    'A00023848', 'A00023866', 'A00024160', 'A00024301', 'A00024372', 'A00024446', 'A00024535', 'A00024546', 
    'A00024663', 'A00024820', 'A00024932', 'A00024955', 'A00025969', 'A00026945', 'A00027487', 'A00027787', 
    'A00028052', 'A00028406', 'A00028409', 'A00029226', 'A00029452', 'A00031478', 'A00031764', 'A00033214', 
    'A00035751', 'A00036049', 'A00036555', 'A00036844', 'A00037007', 'A00037238', 'A00037318', 'A00037495', 
    'A00037564', 'A00037665'
]

# %%
def build_wgan_generator(z_dim):
    # Noise input
    z_input = Input(shape=(z_dim,))

    # Generator network
    model = Sequential()
    
    # Start with a Dense layer to an initial shape that's smaller than the final target
    model.add(Dense(128 * 7 * 7 * 9, input_dim=z_dim))  # Adjust to match an initial volume
    model.add(LeakyReLU(alpha=0.01))
    model.add(Reshape((7, 7, 9, 128)))  # This is the initial volume
    
    # Begin upsampling to the desired size
    model.add(Conv3DTranspose(64, kernel_size=3, strides=2, padding='same'))
    model.add(LeakyReLU(alpha=0.01))
    
    # Continue upsampling
    model.add(Conv3DTranspose(32, kernel_size=3, strides=(3, 3, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.01))
    
    # Final upsampling step to reach just under the target size
    model.add(Conv3DTranspose(1, kernel_size=3, strides=(2, 2, 2), padding='same', activation='tanh'))

    # Output tensor
    output = model(z_input)

    return Model(z_input, output)

# %%
def build_wgan_critic(img_shape):
    # Image input
    img_input = Input(shape=img_shape)

    # Critic network
    x = Conv3D(64, kernel_size=3, strides=2, padding='same')(img_input)
    x = LeakyReLU(alpha=0.01)(x)

    x = Conv3D(128, kernel_size=3, strides=2, padding='same')(x)
    x = LeakyReLU(alpha=0.01)(x)
    
    x = Flatten()(x)
    x = Dense(128)(x)
    x = LeakyReLU(alpha=0.01)(x)
    
    # Output a score for realness (no sigmoid activation)
    output = Dense(1)(x)

    return Model(img_input, output)

# %%
def gradient_penalty(real_images, fake_images, critic):
    batch_size = tf.shape(real_images)[0]

    # Alpha for interpolation - shape: (batch_size, 1, 1, 1, 1)
    alpha = tf.random.uniform([batch_size, 1, 1, 1, 1], 0., 1.)

    # Interpolated images - shape: (batch_size, 84, 84, 72, 1)
    interpolated_images = (real_images * alpha) + (fake_images * (1 - alpha))

    with tf.GradientTape() as tape:
        tape.watch(interpolated_images)
        # Critic now only takes the images as input
        predictions = critic(interpolated_images, training=True)

    # Calculate the gradients with respect to the interpolated images
    gradients = tape.gradient(predictions, [interpolated_images])[0]

    # Compute the norm of the gradients - reduce over all dimensions except the batch dimension
    gradients_norm = tf.sqrt(tf.reduce_sum(tf.square(gradients), axis=[1, 2, 3, 4]))

    # Penalize the gradient norm deviation from 1
    gp = tf.reduce_mean((gradients_norm - 1.) ** 2)
    return gp

# %%
def resize_image(image, new_shape):
    factors = (
        new_shape[0]/image.shape[0],
        new_shape[1]/image.shape[1],
        new_shape[2]/image.shape[2]
    )
    return scipy.ndimage.zoom(image, factors, order=1)  # order=1 is bilinear interpolation

# %%
def train_wgan_gp(generator, critic, dataset, epochs, z_dim, lambda_gp, critic_optimizer, generator_optimizer):
    # Lists to keep track of losses
    critic_losses = []
    generator_losses = []

    # Directory for saving checkpoints
    checkpoint_dir = "wgan_gp_checkpoints"
    if not os.path.exists(checkpoint_dir):
        os.makedirs(checkpoint_dir)

    for epoch in range(epochs):
        epoch_critic_loss = 0.0
        epoch_generator_loss = 0.0
        num_batches = 0
        
        for real_imgs in dataset:
            
            num_batches += 1
            # Ensure real_imgs converts to numpy array
            real_imgs_numpy = real_imgs.numpy() if isinstance(real_imgs, tf.Tensor) else real_imgs

            batch_size = real_imgs_numpy.shape[0]
            print(real_imgs.shape)
            
            # Resize real images to match the expected dimensions of the critic
            real_imgs_resized = np.array([resize_image(img, (84, 84, 72)) for img in real_imgs.numpy()])
            real_imgs_resized = np.expand_dims(real_imgs_resized, axis=-1)  # Add channel dimension

            # Train the critic
            for _ in range(5):  # Critic is often trained more frequently
                with tf.GradientTape() as tape:
                    # Generate fake images
                    z = tf.random.normal([batch_size, z_dim])
                    fake_imgs = generator(z, training=True)

                    # Get critic scores for real and fake images
                    real_output = critic(real_imgs_resized, training=True)
                    fake_output = critic(fake_imgs, training=True)

                    # Calculate critic loss
                    critic_cost = tf.reduce_mean(fake_output) - tf.reduce_mean(real_output)
                    gp = gradient_penalty(real_imgs_resized, fake_imgs, critic)
                    critic_loss = critic_cost + lambda_gp * gp

                # Update critic weights
                critic_grads = tape.gradient(critic_loss, critic.trainable_variables)
                critic_optimizer.apply_gradients(zip(critic_grads, critic.trainable_variables))
                epoch_critic_loss += critic_loss

            # Train the generator
            z = tf.random.normal([batch_size, z_dim])
            

            with tf.GradientTape() as tape:
                fake_imgs = generator(z, training=True)
                fake_output = critic(fake_imgs, training=True)
                generator_loss = -tf.reduce_mean(fake_output)

            # Update generator weights
            generator_grads = tape.gradient(generator_loss, generator.trainable_variables)
            generator_optimizer.apply_gradients(zip(generator_grads, generator.trainable_variables))
            epoch_generator_loss += generator_loss

            # print the losses for each batch
            print(f'Epoch: {epoch}, Batch: {num_batches}, Critic Loss: {critic_loss}, Generator Loss: {generator_loss}')

        # Checkpointing every n epochs
        if (epoch + 1) % 2000 == 0:
            generator.save_weights(os.path.join(checkpoint_dir, f"generator_epoch_{epoch+1}.h5"))
            critic.save_weights(os.path.join(checkpoint_dir, f"critic_epoch_{epoch+1}.h5"))
            print(f"Checkpoint: Saved model weights at epoch {epoch+1}")
            
        # Record the average losses for this epoch
        critic_losses.append(epoch_critic_loss / num_batches)
        generator_losses.append(epoch_generator_loss / num_batches)

    return critic_losses, generator_losses

# %%
def plot_losses(d_losses, g_losses):
    plt.figure(figsize=(10, 5))
    plt.plot(d_losses, label='Discriminator Loss')
    plt.plot(g_losses, label='Generator Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
random.seed(123)

# %%
total_accuracy = 0
total_loss = 0
num_iterations = 1

for i in range(num_iterations):

    ''' data training for GAN '''
    ''' Choosing 50 random schizphrenia samples and store remaining 9 test'''

        # GAN Training Data Selection
    gan_train_ids = random.sample(met_requirement_schizophrenia_ids, 50)
    gan_test_ids = [id for id in met_requirement_schizophrenia_ids if id not in gan_train_ids]

    ''' data training for classifier '''
    ''' Choosing 50 random schizphrenia samples from above and 50 new random control = 100 training'''
    ''' test set here will have the 9 untouch schizophrenia from above plus 9 control that is not included in the training'''

    # Classifier Training Data Selection
    classifier_train_schizophrenia_ids = gan_train_ids  # Using the same set of schizophrenia IDs as GAN
    classifier_train_control_ids = random.sample(met_requirement_control_ids, 50)
    classifier_train_ids = classifier_train_schizophrenia_ids + classifier_train_control_ids

    # Classifier Test Data Selection
    # Ensuring the control IDs for testing are not included in the training set
    remaining_control_ids_for_testing = [id for id in met_requirement_control_ids if id not in classifier_train_control_ids]
    classifier_test_ids = gan_test_ids + random.sample(remaining_control_ids_for_testing, 9)

    ''' File loading '''
    # Specify the directory and file pattern
    directory_path = '../4D'
    file_pattern = 'A*_????_func_FL_FD_RPI_DSP_MCF_SS_SM_Nui_CS_InStandard.nii.gz'

    # Construct the full path pattern
    path_pattern = f'{directory_path}/{file_pattern}'

    # Use glob to find all matching files
    matching_files = glob.glob(path_pattern)

    ''' File loading for GAN Training '''
    # Process only the 50 randomly selected schizophrenia files for GAN training
    gan_image_data = []

    for file_path in matching_files:
        filename = os.path.basename(file_path)
        file_id = filename.split('_')[0]
        
        if file_id in gan_train_ids:
            t1_img = nib.load(file_path)
            t1_data = t1_img.get_fdata()

            if t1_data.shape[3] < 90:
                continue

            t1_data_collapsed = np.sum(t1_data, axis=1)
            gan_image_data.append(t1_data_collapsed)

    print(f"Total GAN training files processed: {len(gan_image_data)}")

    ''' File loading for Classifier Training and Testing '''
    # Process files for both schizophrenia and control for classifier training and testing
    classifier_image_data = []
    classifier_labels = []  # 1 for schizophrenia, 0 for non-schizophrenia

    for file_path in matching_files:
        filename = os.path.basename(file_path)
        file_id = filename.split('_')[0]
        
        if file_id in classifier_train_ids or file_id in classifier_test_ids:
            t1_img = nib.load(file_path)
            t1_data = t1_img.get_fdata()

            if t1_data.shape[3] < 90:
                continue

            label = 1 if file_id in met_requirement_schizophrenia_ids else 0
            t1_data_collapsed = np.sum(t1_data, axis=1)

            classifier_image_data.append(t1_data_collapsed)
            classifier_labels.append(label)

    print(f"Total classifier training/testing files processed: {len(classifier_image_data)}")
    print(f"Total labels processed: {len(classifier_labels)}")

    '''Determine the maximum z-dimension size '''
    max_z_size = max(img.shape[2] for img in gan_image_data)
    max_z_size_2 = max(img.shape[2] for img in classifier_image_data)

    ''' normalization '''
    image_data_normalized = [(img - np.min(img)) / (np.max(img) - np.min(img)) * 2 - 1 for img in gan_image_data]

    image_data_normalized_2 = [(img - np.min(img)) / (np.max(img) - np.min(img)) * 2 - 1 for img in classifier_image_data]

    ''' padding of images data '''
    # Pad each image to have a consistent z-dimension size
    padded_data = [np.pad(img, ((0, 0), (0, 0), (0, max_z_size - img.shape[2])), mode='constant') for img in image_data_normalized]

    padded_data_2 = [np.pad(img, ((0, 0), (0, 0), (0, max_z_size_2 - img.shape[2])), mode='constant') for img in image_data_normalized_2]
    
    # Now convert the padded data list to a numpy array
    padded_data_array = np.array(padded_data)
    padded_data_array_2 = np.array(padded_data_2)

    ''' loading the data for WGAN training '''
    train_images = padded_data_array
    # Define batch size
    batch_size = 10
    train_dataset = tf.data.Dataset.from_tensor_slices((train_images)).shuffle(len(train_images)).batch(batch_size)

    
    ''' setting up parameters'''
    # Image shape and other parameters
    img_shape = (84, 84, 72, 1)
    z_dim = 100

    # Create the generator and critic
    generator = build_wgan_generator(z_dim)
    critic = build_wgan_critic(img_shape)

    critic_optimizer = Adam(learning_rate=0.0001, beta_1=0.5, beta_2=0.999)
    generator_optimizer = Adam(learning_rate=0.0001, beta_1=0.5, beta_2=0.999)

    epochs = 100
    lambda_gp = 10  # Gradient penalty coefficient

    '''Train the WGAN-GP '''

    critic_losses, generator_losses = train_wgan_gp(
        generator, 
        critic, 
        train_dataset, 
        epochs, 
        z_dim,
        lambda_gp, 
        critic_optimizer, 
        generator_optimizer
    )
    
    ''' after training, retrieve the weights of the critic'''

    checkpoint_dir = '/wgan_gp_checkpoints'
    checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
    checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                    discriminator_optimizer=critic_optimizer,
                                    generator=generator,
                                    discriminator=critic)
    
    checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

    ''' transfer learning '''
    
    ''' adding classification layers'''
    new_model = Sequential()
    for i in range(len(critic.layers)-1):  # Excluding the last layer
        layer = critic.layers[i]
        layer.trainable = False  # Freeze the layer
        new_model.add(layer)

    # Adding additional layers
    new_model.add(Dropout(0.3))
    new_model.add(Dense(1, activation='sigmoid', name = 'dense_6'))  # Sigmoid for binary classification

    ''' Prepare data before training the classifer model, 2nd time train '''

    ''' But we include control images to train this time around '''
    # Resize each image in the padded data array
    resized_images = [resize_image(img, (84, 84, 72)) for img in padded_data_2]

    # Convert the resized data to a numpy array
    resized_images_array = np.array(resized_images)

    # Define batch size
    batch_size = 10

    # labels array corresponding to the images
    labels_array = np.array(classifier_labels)
    
    ''' train classifier normally like in transfer-learning v2'''
    # Split the data into training and evaluation sets (80% train, 20% eval)
    X_train, X_eval, y_train, y_eval = train_test_split(resized_images_array, labels_array, test_size=0.2, random_state=42)

    # Convert to TensorFlow datasets with labels
    train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(batch_size)
    eval_dataset = tf.data.Dataset.from_tensor_slices((X_eval, y_eval)).batch(batch_size)

    # Compile the model (if using a new instance of the model for each fold)
    new_model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    history = new_model.fit(
        train_dataset,
        epochs=14,
        validation_data=eval_dataset
    )

    

    ''' load test images to make test set'''
    # Now proceed with loading and preprocessing the images for these IDs
    test_image_data = []
    test_labels = []
    
    test_ids = classifier_test_ids

    # Loop through the matching files and filter based on test IDs
    for file_path in matching_files:
        filename = os.path.basename(file_path)
        file_id = filename.split('_')[0]

        # Process only if the ID is in the test set
        if file_id in test_ids:
            t1_img = nib.load(file_path)
            t1_data = t1_img.get_fdata()

            # Ensure sufficient time dimension
            if t1_data.shape[3] < 90:
                continue

            # Collapse one of the axes by summing
            t1_data_collapsed = np.sum(t1_data, axis=1)

            # Resize, normalize, and add dimension as done in the training data preparation
            processed_image = resize_image(t1_data_collapsed, (84, 84, 72))
            processed_image_normalized = (processed_image - np.min(processed_image)) / (np.max(processed_image) - np.min(processed_image)) * 2 - 1
            processed_image_final = np.expand_dims(processed_image_normalized, axis=-1)

            test_image_data.append(processed_image_final)
            label = 1 if file_id in met_requirement_schizophrenia_ids else 0
            test_labels.append(label)

    # Convert to numpy arrays
    test_images_array = np.array(test_image_data)
    test_labels_array = np.array(test_labels)


    test_dataset = tf.data.Dataset.from_tensor_slices((test_images_array, test_labels_array)).batch(batch_size)
    test_loss = 0
    test_accuracy = 0
    num_batches = 0
    actual_labels = []
    predicted_labels_list = []
    # Manually iterate over the test dataset
    for images, labels in test_dataset:
        # Make predictions
        predictions = new_model.predict(images)

        # Calculate loss for the batch
        loss = tf.keras.losses.binary_crossentropy(labels, predictions)
        test_loss += tf.reduce_mean(loss).numpy()

        # Process predictions
        predicted_labels_batch = tf.cast(tf.round(predictions), dtype=tf.int64)
        predicted_labels_list.extend(predicted_labels_batch.numpy().flatten())
        actual_labels.extend(labels.numpy().flatten())

        # Calculate accuracy for the batch
        accuracy = tf.reduce_mean(tf.cast(tf.equal(labels, predicted_labels_batch), dtype=tf.float32))
        test_accuracy += accuracy.numpy()

        num_batches += 1

    
    iteration_avg_loss = test_loss / num_batches
    iteration_avg_accuracy = test_accuracy / num_batches

    total_loss += iteration_avg_loss
    total_accuracy += iteration_avg_accuracy
    
    # Print test results
    print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
    print("Actual labels vs. Predicted labels:")
    for i in range(len(actual_labels)):
        print(f"Image {i+1}: Actual: {actual_labels[i]}, Predicted: {predicted_labels_list[i]}")

# Calculate and print the average loss and accuracy over all iterations
average_test_loss = total_loss / num_iterations
average_test_accuracy = total_accuracy / num_iterations
print(f"\nAverage Test Loss over {num_iterations} iterations: {average_test_loss}")
print(f"Average Test Accuracy over {num_iterations} iterations: {average_test_accuracy}")
# Out:
# Total GAN training files processed: 50
# Total classifier training/testing files processed: 118
# Total labels processed: 118
# 2024-01-31 03:32:06.312392: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46639 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:17:00.0, compute capability: 8.6
# (10, 91, 91, 146)
# 2024-01-31 03:32:07.802812: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-01-31 03:32:10.455140: I external/local_xla/xla/service/service.cc:168] XLA service 0xaf887f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-01-31 03:32:10.455158: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-01-31 03:32:10.458214: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1706671930.538253 1153455 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f975010c400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f975010c400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch: 0, Batch: 1, Critic Loss: -31.33306121826172, Generator Loss: -0.36374837160110474
# (10, 91, 91, 146)
# Epoch: 0, Batch: 2, Critic Loss: -116.61408233642578, Generator Loss: -0.9941859245300293
# (10, 91, 91, 146)
# Epoch: 0, Batch: 3, Critic Loss: -128.6217041015625, Generator Loss: -1.5113847255706787
# (10, 91, 91, 146)
# Epoch: 0, Batch: 4, Critic Loss: -207.0493927001953, Generator Loss: -1.7531379461288452
# (10, 91, 91, 146)
# Epoch: 0, Batch: 5, Critic Loss: -253.32321166992188, Generator Loss: -1.5955781936645508
# (10, 91, 91, 146)
# Epoch: 1, Batch: 1, Critic Loss: -343.0857849121094, Generator Loss: -1.3074005842208862
# (10, 91, 91, 146)
# Epoch: 1, Batch: 2, Critic Loss: -225.68893432617188, Generator Loss: 0.4955829679965973
# (10, 91, 91, 146)
# Epoch: 1, Batch: 3, Critic Loss: -272.5686950683594, Generator Loss: 11.119962692260742
# (10, 91, 91, 146)
# Epoch: 1, Batch: 4, Critic Loss: -307.3755798339844, Generator Loss: 8.4133882522583
# (10, 91, 91, 146)
# Epoch: 1, Batch: 5, Critic Loss: -365.77935791015625, Generator Loss: 8.056205749511719
# (10, 91, 91, 146)
# Epoch: 2, Batch: 1, Critic Loss: -431.30645751953125, Generator Loss: 7.479485511779785
# (10, 91, 91, 146)
# Epoch: 2, Batch: 2, Critic Loss: -211.72467041015625, Generator Loss: 7.267061710357666
# (10, 91, 91, 146)
# Epoch: 2, Batch: 3, Critic Loss: -359.27850341796875, Generator Loss: 1.5223757028579712
# (10, 91, 91, 146)
# Epoch: 2, Batch: 4, Critic Loss: -353.5881652832031, Generator Loss: -0.2723104953765869
# (10, 91, 91, 146)
# Epoch: 2, Batch: 5, Critic Loss: -219.33901977539062, Generator Loss: 0.019348621368408203
# (10, 91, 91, 146)
# Epoch: 3, Batch: 1, Critic Loss: -321.34869384765625, Generator Loss: -1.4134433269500732
# (10, 91, 91, 146)
# Epoch: 3, Batch: 2, Critic Loss: -335.3043212890625, Generator Loss: -2.5813181400299072
# (10, 91, 91, 146)
# Epoch: 3, Batch: 3, Critic Loss: -352.87799072265625, Generator Loss: -6.847801208496094
# (10, 91, 91, 146)
# Epoch: 3, Batch: 4, Critic Loss: -231.99269104003906, Generator Loss: -5.741389274597168
# (10, 91, 91, 146)
# Epoch: 3, Batch: 5, Critic Loss: -298.8894958496094, Generator Loss: -4.436865329742432
# (10, 91, 91, 146)
# Epoch: 4, Batch: 1, Critic Loss: -345.2042541503906, Generator Loss: -9.580825805664062
# (10, 91, 91, 146)
# Epoch: 4, Batch: 2, Critic Loss: -321.4681701660156, Generator Loss: -13.093507766723633
# (10, 91, 91, 146)
# Epoch: 4, Batch: 3, Critic Loss: -214.84048461914062, Generator Loss: -7.74673318862915
# (10, 91, 91, 146)
# Epoch: 4, Batch: 4, Critic Loss: -308.3526611328125, Generator Loss: -12.952527046203613
# (10, 91, 91, 146)
# Epoch: 4, Batch: 5, Critic Loss: -349.74407958984375, Generator Loss: -18.563533782958984
# (10, 91, 91, 146)
# Epoch: 5, Batch: 1, Critic Loss: -296.8084411621094, Generator Loss: -15.92158317565918
# (10, 91, 91, 146)
# Epoch: 5, Batch: 2, Critic Loss: -182.9094696044922, Generator Loss: -11.8998441696167
# (10, 91, 91, 146)
# Epoch: 5, Batch: 3, Critic Loss: -527.1094360351562, Generator Loss: -39.2706298828125
# (10, 91, 91, 146)
# Epoch: 5, Batch: 4, Critic Loss: -280.1363525390625, Generator Loss: -22.652240753173828
# (10, 91, 91, 146)
# Epoch: 5, Batch: 5, Critic Loss: -250.39263916015625, Generator Loss: -22.8725643157959
# (10, 91, 91, 146)
# Epoch: 6, Batch: 1, Critic Loss: -270.62689208984375, Generator Loss: -22.793590545654297
# (10, 91, 91, 146)
# Epoch: 6, Batch: 2, Critic Loss: -287.3638916015625, Generator Loss: -25.058168411254883
# (10, 91, 91, 146)
# Epoch: 6, Batch: 3, Critic Loss: -265.1139831542969, Generator Loss: -29.760915756225586
# (10, 91, 91, 146)
# Epoch: 6, Batch: 4, Critic Loss: -479.6361389160156, Generator Loss: -57.15489959716797
# (10, 91, 91, 146)
# Epoch: 6, Batch: 5, Critic Loss: -253.45457458496094, Generator Loss: -37.41013717651367
# (10, 91, 91, 146)
# Epoch: 7, Batch: 1, Critic Loss: -319.93426513671875, Generator Loss: -41.485321044921875
# (10, 91, 91, 146)
# Epoch: 7, Batch: 2, Critic Loss: -400.9488220214844, Generator Loss: -55.03618240356445
# (10, 91, 91, 146)
# Epoch: 7, Batch: 3, Critic Loss: -280.68292236328125, Generator Loss: -41.60246658325195
# (10, 91, 91, 146)
# Epoch: 7, Batch: 4, Critic Loss: -175.40956115722656, Generator Loss: -23.417682647705078
# (10, 91, 91, 146)
# Epoch: 7, Batch: 5, Critic Loss: -303.67779541015625, Generator Loss: -41.043800354003906
# (10, 91, 91, 146)
# Epoch: 8, Batch: 1, Critic Loss: -273.20867919921875, Generator Loss: -41.798553466796875
# (10, 91, 91, 146)
# Epoch: 8, Batch: 2, Critic Loss: -285.093505859375, Generator Loss: -45.23845672607422
# (10, 91, 91, 146)
# Epoch: 8, Batch: 3, Critic Loss: -184.8700408935547, Generator Loss: -7.67935848236084
# (10, 91, 91, 146)
# Epoch: 8, Batch: 4, Critic Loss: -374.5233154296875, Generator Loss: -71.23805236816406
# (10, 91, 91, 146)
# Epoch: 8, Batch: 5, Critic Loss: -422.2990417480469, Generator Loss: -65.29144287109375
# (10, 91, 91, 146)
# Epoch: 9, Batch: 1, Critic Loss: -317.16259765625, Generator Loss: -45.0549430847168
# (10, 91, 91, 146)
# Epoch: 9, Batch: 2, Critic Loss: -158.78857421875, Generator Loss: -27.646127700805664
# (10, 91, 91, 146)
# Epoch: 9, Batch: 3, Critic Loss: -342.78436279296875, Generator Loss: -51.97905731201172
# (10, 91, 91, 146)
# Epoch: 9, Batch: 4, Critic Loss: -321.9517517089844, Generator Loss: -70.64495849609375
# (10, 91, 91, 146)
# Epoch: 9, Batch: 5, Critic Loss: -309.24603271484375, Generator Loss: -68.12174987792969
# (10, 91, 91, 146)
# Epoch: 10, Batch: 1, Critic Loss: -235.52450561523438, Generator Loss: -4.178262233734131
# (10, 91, 91, 146)
# Epoch: 10, Batch: 2, Critic Loss: -181.78677368164062, Generator Loss: 5.448672771453857
# (10, 91, 91, 146)
# Epoch: 10, Batch: 3, Critic Loss: -280.48291015625, Generator Loss: -52.83855056762695
# (10, 91, 91, 146)
# Epoch: 10, Batch: 4, Critic Loss: -315.68798828125, Generator Loss: -77.03665924072266
# (10, 91, 91, 146)
# Epoch: 10, Batch: 5, Critic Loss: -437.8931579589844, Generator Loss: -103.514404296875
# (10, 91, 91, 146)
# Epoch: 11, Batch: 1, Critic Loss: -286.5603942871094, Generator Loss: -50.35829162597656
# (10, 91, 91, 146)
# Epoch: 11, Batch: 2, Critic Loss: -207.38499450683594, Generator Loss: -33.399349212646484
# (10, 91, 91, 146)
# Epoch: 11, Batch: 3, Critic Loss: -240.99517822265625, Generator Loss: -55.63850784301758
# (10, 91, 91, 146)
# Epoch: 11, Batch: 4, Critic Loss: -374.60009765625, Generator Loss: -87.14595031738281
# (10, 91, 91, 146)
# Epoch: 11, Batch: 5, Critic Loss: -339.202880859375, Generator Loss: -101.71669006347656
# (10, 91, 91, 146)
# Epoch: 12, Batch: 1, Critic Loss: -342.8324279785156, Generator Loss: -95.97647857666016
# (10, 91, 91, 146)
# Epoch: 12, Batch: 2, Critic Loss: -218.7728271484375, Generator Loss: -41.817508697509766
# (10, 91, 91, 146)
# Epoch: 12, Batch: 3, Critic Loss: -266.1706848144531, Generator Loss: -77.12445068359375
# (10, 91, 91, 146)
# Epoch: 12, Batch: 4, Critic Loss: -293.99664306640625, Generator Loss: -46.64396667480469
# (10, 91, 91, 146)
# Epoch: 12, Batch: 5, Critic Loss: -275.59259033203125, Generator Loss: -137.04873657226562
# (10, 91, 91, 146)
# Epoch: 13, Batch: 1, Critic Loss: -345.8305358886719, Generator Loss: -57.23492431640625
# (10, 91, 91, 146)
# Epoch: 13, Batch: 2, Critic Loss: -327.86846923828125, Generator Loss: -127.23284912109375
# (10, 91, 91, 146)
# Epoch: 13, Batch: 3, Critic Loss: -197.2993621826172, Generator Loss: -46.93212890625
# (10, 91, 91, 146)
# Epoch: 13, Batch: 4, Critic Loss: -322.3172607421875, Generator Loss: -151.2100830078125
# (10, 91, 91, 146)
# Epoch: 13, Batch: 5, Critic Loss: -255.53570556640625, Generator Loss: -91.00052642822266
# (10, 91, 91, 146)
# Epoch: 14, Batch: 1, Critic Loss: -221.58792114257812, Generator Loss: -108.5514144897461
# (10, 91, 91, 146)
# Epoch: 14, Batch: 2, Critic Loss: -228.97442626953125, Generator Loss: -19.20670509338379
# (10, 91, 91, 146)
# Epoch: 14, Batch: 3, Critic Loss: -280.5746154785156, Generator Loss: -94.7551498413086
# (10, 91, 91, 146)
# Epoch: 14, Batch: 4, Critic Loss: -293.8709716796875, Generator Loss: -102.8582534790039
# (10, 91, 91, 146)
# Epoch: 14, Batch: 5, Critic Loss: -244.32745361328125, Generator Loss: -134.99134826660156
# (10, 91, 91, 146)
# Epoch: 15, Batch: 1, Critic Loss: -195.8475341796875, Generator Loss: -60.709190368652344
# (10, 91, 91, 146)
# Epoch: 15, Batch: 2, Critic Loss: -235.73196411132812, Generator Loss: -127.60929870605469
# (10, 91, 91, 146)
# Epoch: 15, Batch: 3, Critic Loss: -253.04188537597656, Generator Loss: -119.4798583984375
# (10, 91, 91, 146)
# Epoch: 15, Batch: 4, Critic Loss: -376.8876037597656, Generator Loss: -127.01155853271484
# (10, 91, 91, 146)
# Epoch: 15, Batch: 5, Critic Loss: -265.093505859375, Generator Loss: -63.35558319091797
# (10, 91, 91, 146)
# Epoch: 16, Batch: 1, Critic Loss: -263.3212585449219, Generator Loss: -123.66801452636719
# (10, 91, 91, 146)
# Epoch: 16, Batch: 2, Critic Loss: -324.63800048828125, Generator Loss: -149.266357421875
# (10, 91, 91, 146)
# Epoch: 16, Batch: 3, Critic Loss: -290.62548828125, Generator Loss: -87.5560073852539
# (10, 91, 91, 146)
# Epoch: 16, Batch: 4, Critic Loss: -236.10601806640625, Generator Loss: -115.9472885131836
# (10, 91, 91, 146)
# Epoch: 16, Batch: 5, Critic Loss: -182.74737548828125, Generator Loss: -134.70785522460938
# (10, 91, 91, 146)
# Epoch: 17, Batch: 1, Critic Loss: -173.95237731933594, Generator Loss: -93.27630615234375
# (10, 91, 91, 146)
# Epoch: 17, Batch: 2, Critic Loss: -250.403564453125, Generator Loss: -58.077392578125
# (10, 91, 91, 146)
# Epoch: 17, Batch: 3, Critic Loss: -297.16094970703125, Generator Loss: -80.46023559570312
# (10, 91, 91, 146)
# Epoch: 17, Batch: 4, Critic Loss: -236.98593139648438, Generator Loss: -159.1507568359375
# (10, 91, 91, 146)
# Epoch: 17, Batch: 5, Critic Loss: -324.17022705078125, Generator Loss: -125.4120864868164
# (10, 91, 91, 146)
# Epoch: 18, Batch: 1, Critic Loss: -197.20880126953125, Generator Loss: -112.54466247558594
# (10, 91, 91, 146)
# Epoch: 18, Batch: 2, Critic Loss: -224.00660705566406, Generator Loss: -175.98992919921875
# (10, 91, 91, 146)
# Epoch: 18, Batch: 3, Critic Loss: -267.77752685546875, Generator Loss: -152.1636962890625
# (10, 91, 91, 146)
# Epoch: 18, Batch: 4, Critic Loss: -416.6717834472656, Generator Loss: -114.20436096191406
# (10, 91, 91, 146)
# Epoch: 18, Batch: 5, Critic Loss: -207.88327026367188, Generator Loss: -172.82154846191406
# (10, 91, 91, 146)
# Epoch: 19, Batch: 1, Critic Loss: -229.04580688476562, Generator Loss: -135.6328582763672
# (10, 91, 91, 146)
# Epoch: 19, Batch: 2, Critic Loss: -261.5324401855469, Generator Loss: -105.1883316040039
# (10, 91, 91, 146)
# Epoch: 19, Batch: 3, Critic Loss: -259.60791015625, Generator Loss: -126.8076171875
# (10, 91, 91, 146)
# Epoch: 19, Batch: 4, Critic Loss: -199.24664306640625, Generator Loss: -107.57890319824219
# (10, 91, 91, 146)
# Epoch: 19, Batch: 5, Critic Loss: -295.2066955566406, Generator Loss: -189.74972534179688
# (10, 91, 91, 146)
# Epoch: 20, Batch: 1, Critic Loss: -189.13247680664062, Generator Loss: -90.82600402832031
# (10, 91, 91, 146)
# Epoch: 20, Batch: 2, Critic Loss: -269.1146545410156, Generator Loss: -206.78262329101562
# (10, 91, 91, 146)
# Epoch: 20, Batch: 3, Critic Loss: -214.57748413085938, Generator Loss: -135.40518188476562
# (10, 91, 91, 146)
# Epoch: 20, Batch: 4, Critic Loss: -235.55941772460938, Generator Loss: -138.23239135742188
# (10, 91, 91, 146)
# Epoch: 20, Batch: 5, Critic Loss: -268.5130920410156, Generator Loss: -145.15847778320312
# (10, 91, 91, 146)
# Epoch: 21, Batch: 1, Critic Loss: -352.33624267578125, Generator Loss: -92.38079833984375
# (10, 91, 91, 146)
# Epoch: 21, Batch: 2, Critic Loss: -201.87600708007812, Generator Loss: -148.92404174804688
# (10, 91, 91, 146)
# Epoch: 21, Batch: 3, Critic Loss: -238.71255493164062, Generator Loss: -172.428955078125
# (10, 91, 91, 146)
# Epoch: 21, Batch: 4, Critic Loss: -155.19573974609375, Generator Loss: -99.46214294433594
# (10, 91, 91, 146)
# Epoch: 21, Batch: 5, Critic Loss: -233.21676635742188, Generator Loss: -110.9050521850586
# (10, 91, 91, 146)
# Epoch: 22, Batch: 1, Critic Loss: -260.074951171875, Generator Loss: -105.64481353759766
# (10, 91, 91, 146)
# Epoch: 22, Batch: 2, Critic Loss: -161.7939910888672, Generator Loss: -133.23402404785156
# (10, 91, 91, 146)
# Epoch: 22, Batch: 3, Critic Loss: -309.12158203125, Generator Loss: -198.01101684570312
# (10, 91, 91, 146)
# Epoch: 22, Batch: 4, Critic Loss: -244.2628631591797, Generator Loss: -119.55267333984375
# (10, 91, 91, 146)
# Epoch: 22, Batch: 5, Critic Loss: -156.00399780273438, Generator Loss: -174.249267578125
# (10, 91, 91, 146)
# Epoch: 23, Batch: 1, Critic Loss: -175.72503662109375, Generator Loss: -85.70475769042969
# (10, 91, 91, 146)
# Epoch: 23, Batch: 2, Critic Loss: -158.00726318359375, Generator Loss: -136.20455932617188
# (10, 91, 91, 146)
# Epoch: 23, Batch: 3, Critic Loss: -317.00439453125, Generator Loss: -282.3396301269531
# (10, 91, 91, 146)
# Epoch: 23, Batch: 4, Critic Loss: -295.43438720703125, Generator Loss: -168.5953826904297
# (10, 91, 91, 146)
# Epoch: 23, Batch: 5, Critic Loss: -279.9700622558594, Generator Loss: -173.946044921875
# (10, 91, 91, 146)
# Epoch: 24, Batch: 1, Critic Loss: -231.42379760742188, Generator Loss: -243.09701538085938
# (10, 91, 91, 146)
# Epoch: 24, Batch: 2, Critic Loss: -143.00205993652344, Generator Loss: -174.93089294433594
# (10, 91, 91, 146)
# Epoch: 24, Batch: 3, Critic Loss: -182.967041015625, Generator Loss: -231.99911499023438
# (10, 91, 91, 146)
# Epoch: 24, Batch: 4, Critic Loss: -300.8685607910156, Generator Loss: -260.5220642089844
# (10, 91, 91, 146)
# Epoch: 24, Batch: 5, Critic Loss: -240.6673583984375, Generator Loss: -243.37625122070312
# (10, 91, 91, 146)
# Epoch: 25, Batch: 1, Critic Loss: -258.9071960449219, Generator Loss: -248.81234741210938
# (10, 91, 91, 146)
# Epoch: 25, Batch: 2, Critic Loss: -182.5343475341797, Generator Loss: -145.84625244140625
# (10, 91, 91, 146)
# Epoch: 25, Batch: 3, Critic Loss: -134.36007690429688, Generator Loss: -252.0909881591797
# (10, 91, 91, 146)
# Epoch: 25, Batch: 4, Critic Loss: -338.2436828613281, Generator Loss: -182.5221405029297
# (10, 91, 91, 146)
# Epoch: 25, Batch: 5, Critic Loss: -203.9359130859375, Generator Loss: -97.61229705810547
# (10, 91, 91, 146)
# Epoch: 26, Batch: 1, Critic Loss: -176.253662109375, Generator Loss: -176.2420654296875
# (10, 91, 91, 146)
# Epoch: 26, Batch: 2, Critic Loss: -437.12896728515625, Generator Loss: -231.38720703125
# (10, 91, 91, 146)
# Epoch: 26, Batch: 3, Critic Loss: -156.97015380859375, Generator Loss: -137.10719299316406
# (10, 91, 91, 146)
# Epoch: 26, Batch: 4, Critic Loss: -153.37594604492188, Generator Loss: -162.94009399414062
# (10, 91, 91, 146)
# Epoch: 26, Batch: 5, Critic Loss: -231.23751831054688, Generator Loss: -216.79953002929688
# (10, 91, 91, 146)
# Epoch: 27, Batch: 1, Critic Loss: -368.11920166015625, Generator Loss: -234.33633422851562
# (10, 91, 91, 146)
# Epoch: 27, Batch: 2, Critic Loss: -178.9559326171875, Generator Loss: -203.96189880371094
# (10, 91, 91, 146)
# Epoch: 27, Batch: 3, Critic Loss: -251.14144897460938, Generator Loss: -226.22146606445312
# (10, 91, 91, 146)
# Epoch: 27, Batch: 4, Critic Loss: -119.86381530761719, Generator Loss: -168.0541534423828
# (10, 91, 91, 146)
# Epoch: 27, Batch: 5, Critic Loss: -150.81869506835938, Generator Loss: -197.2433319091797
# (10, 91, 91, 146)
# Epoch: 28, Batch: 1, Critic Loss: -238.17315673828125, Generator Loss: -193.77891540527344
# (10, 91, 91, 146)
# Epoch: 28, Batch: 2, Critic Loss: -177.775634765625, Generator Loss: -207.768798828125
# (10, 91, 91, 146)
# Epoch: 28, Batch: 3, Critic Loss: -265.0027160644531, Generator Loss: -274.44415283203125
# (10, 91, 91, 146)
# Epoch: 28, Batch: 4, Critic Loss: -163.46742248535156, Generator Loss: -151.0865936279297
# (10, 91, 91, 146)
# Epoch: 28, Batch: 5, Critic Loss: -165.02947998046875, Generator Loss: -154.889404296875
# (10, 91, 91, 146)
# Epoch: 29, Batch: 1, Critic Loss: -228.89845275878906, Generator Loss: -164.70187377929688
# (10, 91, 91, 146)
# Epoch: 29, Batch: 2, Critic Loss: -138.96981811523438, Generator Loss: -161.57301330566406
# (10, 91, 91, 146)
# Epoch: 29, Batch: 3, Critic Loss: -183.8734588623047, Generator Loss: -154.0985565185547
# (10, 91, 91, 146)
# Epoch: 29, Batch: 4, Critic Loss: -240.53192138671875, Generator Loss: -268.01666259765625
# (10, 91, 91, 146)
# Epoch: 29, Batch: 5, Critic Loss: -114.19580078125, Generator Loss: -197.77444458007812
# (10, 91, 91, 146)
# Epoch: 30, Batch: 1, Critic Loss: -277.8179931640625, Generator Loss: -278.4247741699219
# (10, 91, 91, 146)
# Epoch: 30, Batch: 2, Critic Loss: -149.36395263671875, Generator Loss: -136.67987060546875
# (10, 91, 91, 146)
# Epoch: 30, Batch: 3, Critic Loss: -190.9335479736328, Generator Loss: -109.6786117553711
# (10, 91, 91, 146)
# Epoch: 30, Batch: 4, Critic Loss: -161.71385192871094, Generator Loss: -117.9361801147461
# (10, 91, 91, 146)
# Epoch: 30, Batch: 5, Critic Loss: -173.682861328125, Generator Loss: -148.32174682617188
# (10, 91, 91, 146)
# Epoch: 31, Batch: 1, Critic Loss: -190.24200439453125, Generator Loss: -236.30203247070312
# (10, 91, 91, 146)
# Epoch: 31, Batch: 2, Critic Loss: -92.85664367675781, Generator Loss: -60.0015983581543
# (10, 91, 91, 146)
# Epoch: 31, Batch: 3, Critic Loss: -333.1304626464844, Generator Loss: -230.3673553466797
# (10, 91, 91, 146)
# Epoch: 31, Batch: 4, Critic Loss: -229.45628356933594, Generator Loss: -82.1085433959961
# (10, 91, 91, 146)
# Epoch: 31, Batch: 5, Critic Loss: -135.64840698242188, Generator Loss: -186.23062133789062
# (10, 91, 91, 146)
# Epoch: 32, Batch: 1, Critic Loss: -208.6204833984375, Generator Loss: -140.54702758789062
# (10, 91, 91, 146)
# Epoch: 32, Batch: 2, Critic Loss: -183.12437438964844, Generator Loss: -120.4781494140625
# (10, 91, 91, 146)
# Epoch: 32, Batch: 3, Critic Loss: -181.97024536132812, Generator Loss: -225.63088989257812
# (10, 91, 91, 146)
# Epoch: 32, Batch: 4, Critic Loss: -150.69992065429688, Generator Loss: -164.96084594726562
# (10, 91, 91, 146)
# Epoch: 32, Batch: 5, Critic Loss: -224.22120666503906, Generator Loss: -208.28384399414062
# (10, 91, 91, 146)
# Epoch: 33, Batch: 1, Critic Loss: -263.10833740234375, Generator Loss: -338.9739685058594
# (10, 91, 91, 146)
# Epoch: 33, Batch: 2, Critic Loss: -111.97872161865234, Generator Loss: -132.28236389160156
# (10, 91, 91, 146)
# Epoch: 33, Batch: 3, Critic Loss: -201.1824493408203, Generator Loss: -122.13736724853516
# (10, 91, 91, 146)
# Epoch: 33, Batch: 4, Critic Loss: -131.42221069335938, Generator Loss: -105.04852294921875
# (10, 91, 91, 146)
# Epoch: 33, Batch: 5, Critic Loss: -157.0556640625, Generator Loss: -165.51657104492188
# (10, 91, 91, 146)
# Epoch: 34, Batch: 1, Critic Loss: -217.6729736328125, Generator Loss: -180.65176391601562
# (10, 91, 91, 146)
# Epoch: 34, Batch: 2, Critic Loss: -161.5163116455078, Generator Loss: -96.44439697265625
# (10, 91, 91, 146)
# Epoch: 34, Batch: 3, Critic Loss: -117.73512268066406, Generator Loss: -83.93182373046875
# (10, 91, 91, 146)
# Epoch: 34, Batch: 4, Critic Loss: -198.40386962890625, Generator Loss: -138.5995635986328
# (10, 91, 91, 146)
# Epoch: 34, Batch: 5, Critic Loss: -165.31736755371094, Generator Loss: -194.8541717529297
# (10, 91, 91, 146)
# Epoch: 35, Batch: 1, Critic Loss: -238.6836395263672, Generator Loss: -152.77059936523438
# (10, 91, 91, 146)
# Epoch: 35, Batch: 2, Critic Loss: -172.87628173828125, Generator Loss: -122.37740325927734
# (10, 91, 91, 146)
# Epoch: 35, Batch: 3, Critic Loss: -233.0, Generator Loss: -246.0195770263672
# (10, 91, 91, 146)
# Epoch: 35, Batch: 4, Critic Loss: -167.7508087158203, Generator Loss: -160.6533203125
# (10, 91, 91, 146)
# Epoch: 35, Batch: 5, Critic Loss: -114.15472412109375, Generator Loss: -102.00029754638672
# (10, 91, 91, 146)
# Epoch: 36, Batch: 1, Critic Loss: -157.8084259033203, Generator Loss: -153.98294067382812
# (10, 91, 91, 146)
# Epoch: 36, Batch: 2, Critic Loss: -81.42838287353516, Generator Loss: -86.02565002441406
# (10, 91, 91, 146)
# Epoch: 36, Batch: 3, Critic Loss: -287.85302734375, Generator Loss: -178.3974609375
# (10, 91, 91, 146)
# Epoch: 36, Batch: 4, Critic Loss: -196.2060546875, Generator Loss: -244.1121826171875
# (10, 91, 91, 146)
# Epoch: 36, Batch: 5, Critic Loss: -117.16963195800781, Generator Loss: -180.38412475585938
# (10, 91, 91, 146)
# Epoch: 37, Batch: 1, Critic Loss: -227.01153564453125, Generator Loss: -240.97933959960938
# (10, 91, 91, 146)
# Epoch: 37, Batch: 2, Critic Loss: -110.81483459472656, Generator Loss: -120.40885925292969
# (10, 91, 91, 146)
# Epoch: 37, Batch: 3, Critic Loss: -192.67510986328125, Generator Loss: -173.5324249267578
# (10, 91, 91, 146)
# Epoch: 37, Batch: 4, Critic Loss: -155.1531219482422, Generator Loss: -120.7763671875
# (10, 91, 91, 146)
# Epoch: 37, Batch: 5, Critic Loss: -165.8209991455078, Generator Loss: -108.30329895019531
# (10, 91, 91, 146)
# Epoch: 38, Batch: 1, Critic Loss: -213.5638427734375, Generator Loss: -194.7274169921875
# (10, 91, 91, 146)
# Epoch: 38, Batch: 2, Critic Loss: -166.9440460205078, Generator Loss: -151.48641967773438
# (10, 91, 91, 146)
# Epoch: 38, Batch: 3, Critic Loss: -148.137451171875, Generator Loss: -122.1183090209961
# (10, 91, 91, 146)
# Epoch: 38, Batch: 4, Critic Loss: -62.91424560546875, Generator Loss: -135.6265106201172
# (10, 91, 91, 146)
# Epoch: 38, Batch: 5, Critic Loss: -156.8174285888672, Generator Loss: -77.37823486328125
# (10, 91, 91, 146)
# Epoch: 39, Batch: 1, Critic Loss: -168.82740783691406, Generator Loss: -155.02499389648438
# (10, 91, 91, 146)
# Epoch: 39, Batch: 2, Critic Loss: -197.88101196289062, Generator Loss: -172.1369171142578
# (10, 91, 91, 146)
# Epoch: 39, Batch: 3, Critic Loss: -120.34663391113281, Generator Loss: -102.49586486816406
# (10, 91, 91, 146)
# Epoch: 39, Batch: 4, Critic Loss: -103.21783447265625, Generator Loss: -106.8787841796875
# (10, 91, 91, 146)
# Epoch: 39, Batch: 5, Critic Loss: -133.189697265625, Generator Loss: -118.6976318359375
# (10, 91, 91, 146)
# Epoch: 40, Batch: 1, Critic Loss: -163.2406768798828, Generator Loss: -125.2511978149414
# (10, 91, 91, 146)
# Epoch: 40, Batch: 2, Critic Loss: -199.7930450439453, Generator Loss: -240.5717315673828
# (10, 91, 91, 146)
# Epoch: 40, Batch: 3, Critic Loss: -158.12818908691406, Generator Loss: -226.8624267578125
# (10, 91, 91, 146)
# Epoch: 40, Batch: 4, Critic Loss: -131.61029052734375, Generator Loss: -78.347900390625
# (10, 91, 91, 146)
# Epoch: 40, Batch: 5, Critic Loss: -182.8563995361328, Generator Loss: -109.91583251953125
# (10, 91, 91, 146)
# Epoch: 41, Batch: 1, Critic Loss: -91.07604217529297, Generator Loss: -67.90638732910156
# (10, 91, 91, 146)
# Epoch: 41, Batch: 2, Critic Loss: -236.9698486328125, Generator Loss: -143.75759887695312
# (10, 91, 91, 146)
# Epoch: 41, Batch: 3, Critic Loss: -101.64115905761719, Generator Loss: -29.941797256469727
# (10, 91, 91, 146)
# Epoch: 41, Batch: 4, Critic Loss: -227.4331817626953, Generator Loss: -92.26702880859375
# (10, 91, 91, 146)
# Epoch: 41, Batch: 5, Critic Loss: -131.20907592773438, Generator Loss: -57.02159881591797
# (10, 91, 91, 146)
# Epoch: 42, Batch: 1, Critic Loss: -95.26868438720703, Generator Loss: -110.30339050292969
# (10, 91, 91, 146)
# Epoch: 42, Batch: 2, Critic Loss: -322.7867431640625, Generator Loss: -115.00767517089844
# (10, 91, 91, 146)
# Epoch: 42, Batch: 3, Critic Loss: -173.17906188964844, Generator Loss: -66.4098892211914
# (10, 91, 91, 146)
# Epoch: 42, Batch: 4, Critic Loss: -115.50843811035156, Generator Loss: 35.74119186401367
# (10, 91, 91, 146)
# Epoch: 42, Batch: 5, Critic Loss: -125.31961059570312, Generator Loss: -64.49111938476562
# (10, 91, 91, 146)
# Epoch: 43, Batch: 1, Critic Loss: -199.88409423828125, Generator Loss: -182.02081298828125
# (10, 91, 91, 146)
# Epoch: 43, Batch: 2, Critic Loss: -94.8487319946289, Generator Loss: -81.63250732421875
# (10, 91, 91, 146)
# Epoch: 43, Batch: 3, Critic Loss: -93.53734588623047, Generator Loss: -74.69481658935547
# (10, 91, 91, 146)
# Epoch: 43, Batch: 4, Critic Loss: -257.4773254394531, Generator Loss: -77.22950744628906
# (10, 91, 91, 146)
# Epoch: 43, Batch: 5, Critic Loss: -118.19007873535156, Generator Loss: -54.19965362548828
# (10, 91, 91, 146)
# Epoch: 44, Batch: 1, Critic Loss: -151.47303771972656, Generator Loss: -31.029766082763672
# (10, 91, 91, 146)
# Epoch: 44, Batch: 2, Critic Loss: -112.33940124511719, Generator Loss: -86.90571594238281
# (10, 91, 91, 146)
# Epoch: 44, Batch: 3, Critic Loss: -154.4808807373047, Generator Loss: -135.11590576171875
# (10, 91, 91, 146)
# Epoch: 44, Batch: 4, Critic Loss: -153.44337463378906, Generator Loss: -132.97653198242188
# (10, 91, 91, 146)
# Epoch: 44, Batch: 5, Critic Loss: -147.06556701660156, Generator Loss: -91.36660766601562
# (10, 91, 91, 146)
# Epoch: 45, Batch: 1, Critic Loss: -83.01239013671875, Generator Loss: -65.55734252929688
# (10, 91, 91, 146)
# Epoch: 45, Batch: 2, Critic Loss: -115.51918029785156, Generator Loss: -35.817649841308594
# (10, 91, 91, 146)
# Epoch: 45, Batch: 3, Critic Loss: -237.0184783935547, Generator Loss: -201.71926879882812
# (10, 91, 91, 146)
# Epoch: 45, Batch: 4, Critic Loss: -92.34297180175781, Generator Loss: -134.7140655517578
# (10, 91, 91, 146)
# Epoch: 45, Batch: 5, Critic Loss: -184.92767333984375, Generator Loss: -145.42034912109375
# (10, 91, 91, 146)
# Epoch: 46, Batch: 1, Critic Loss: -245.73426818847656, Generator Loss: -167.39462280273438
# (10, 91, 91, 146)
# Epoch: 46, Batch: 2, Critic Loss: -104.53012084960938, Generator Loss: -121.39228820800781
# (10, 91, 91, 146)
# Epoch: 46, Batch: 3, Critic Loss: -125.60383605957031, Generator Loss: -184.44796752929688
# (10, 91, 91, 146)
# Epoch: 46, Batch: 4, Critic Loss: -127.29204559326172, Generator Loss: -68.23402404785156
# (10, 91, 91, 146)
# Epoch: 46, Batch: 5, Critic Loss: -138.6305389404297, Generator Loss: -10.468409538269043
# (10, 91, 91, 146)
# Epoch: 47, Batch: 1, Critic Loss: -194.26443481445312, Generator Loss: -45.69743728637695
# (10, 91, 91, 146)
# Epoch: 47, Batch: 2, Critic Loss: -192.00343322753906, Generator Loss: -89.41188049316406
# (10, 91, 91, 146)
# Epoch: 47, Batch: 3, Critic Loss: -118.08555603027344, Generator Loss: -243.4463348388672
# (10, 91, 91, 146)
# Epoch: 47, Batch: 4, Critic Loss: -114.65900421142578, Generator Loss: -39.34613800048828
# (10, 91, 91, 146)
# Epoch: 47, Batch: 5, Critic Loss: -156.5965118408203, Generator Loss: -74.9913101196289
# (10, 91, 91, 146)
# Epoch: 48, Batch: 1, Critic Loss: -95.80528259277344, Generator Loss: -18.99957275390625
# (10, 91, 91, 146)
# Epoch: 48, Batch: 2, Critic Loss: -124.85565185546875, Generator Loss: -18.107580184936523
# (10, 91, 91, 146)
# Epoch: 48, Batch: 3, Critic Loss: -249.5657958984375, Generator Loss: 49.62376403808594
# (10, 91, 91, 146)
# Epoch: 48, Batch: 4, Critic Loss: -96.76451873779297, Generator Loss: -30.334497451782227
# (10, 91, 91, 146)
# Epoch: 48, Batch: 5, Critic Loss: -118.70903015136719, Generator Loss: -117.3919677734375
# (10, 91, 91, 146)
# Epoch: 49, Batch: 1, Critic Loss: -138.6732635498047, Generator Loss: -76.09791564941406
# (10, 91, 91, 146)
# Epoch: 49, Batch: 2, Critic Loss: -145.2373046875, Generator Loss: -69.85325622558594
# (10, 91, 91, 146)
# Epoch: 49, Batch: 3, Critic Loss: -128.929931640625, Generator Loss: -76.93553161621094
# (10, 91, 91, 146)
# Epoch: 49, Batch: 4, Critic Loss: -105.49560546875, Generator Loss: -49.84747314453125
# (10, 91, 91, 146)
# Epoch: 49, Batch: 5, Critic Loss: -114.822265625, Generator Loss: 4.046865940093994
# (10, 91, 91, 146)
# Epoch: 50, Batch: 1, Critic Loss: -110.09918212890625, Generator Loss: 63.03911209106445
# (10, 91, 91, 146)
# Epoch: 50, Batch: 2, Critic Loss: -151.45529174804688, Generator Loss: 41.338706970214844
# (10, 91, 91, 146)
# Epoch: 50, Batch: 3, Critic Loss: -196.9483184814453, Generator Loss: -92.17774200439453
# (10, 91, 91, 146)
# Epoch: 50, Batch: 4, Critic Loss: -181.15028381347656, Generator Loss: 42.08910369873047
# (10, 91, 91, 146)
# Epoch: 50, Batch: 5, Critic Loss: -172.297119140625, Generator Loss: -39.75748062133789
# (10, 91, 91, 146)
# Epoch: 51, Batch: 1, Critic Loss: -164.3455810546875, Generator Loss: -44.61646270751953
# (10, 91, 91, 146)
# Epoch: 51, Batch: 2, Critic Loss: -102.34577941894531, Generator Loss: 111.6328125
# (10, 91, 91, 146)
# Epoch: 51, Batch: 3, Critic Loss: -118.10722351074219, Generator Loss: -46.93882369995117
# (10, 91, 91, 146)
# Epoch: 51, Batch: 4, Critic Loss: -104.61766052246094, Generator Loss: -8.951330184936523
# (10, 91, 91, 146)
# Epoch: 51, Batch: 5, Critic Loss: -126.99267578125, Generator Loss: -74.84040832519531
# (10, 91, 91, 146)
# Epoch: 52, Batch: 1, Critic Loss: -191.5936737060547, Generator Loss: -46.715065002441406
# (10, 91, 91, 146)
# Epoch: 52, Batch: 2, Critic Loss: -167.63372802734375, Generator Loss: -85.40017700195312
# (10, 91, 91, 146)
# Epoch: 52, Batch: 3, Critic Loss: -89.2548599243164, Generator Loss: -0.14523467421531677
# (10, 91, 91, 146)
# Epoch: 52, Batch: 4, Critic Loss: -149.0411834716797, Generator Loss: -19.454605102539062
# (10, 91, 91, 146)
# Epoch: 52, Batch: 5, Critic Loss: -170.84011840820312, Generator Loss: 41.7105712890625
# (10, 91, 91, 146)
# Epoch: 53, Batch: 1, Critic Loss: -98.99360656738281, Generator Loss: 13.053359985351562
# (10, 91, 91, 146)
# Epoch: 53, Batch: 2, Critic Loss: -133.1191864013672, Generator Loss: 68.0411605834961
# (10, 91, 91, 146)
# Epoch: 53, Batch: 3, Critic Loss: -159.346435546875, Generator Loss: 8.896641731262207
# (10, 91, 91, 146)
# Epoch: 53, Batch: 4, Critic Loss: -184.01995849609375, Generator Loss: -68.476318359375
# (10, 91, 91, 146)
# Epoch: 53, Batch: 5, Critic Loss: -79.17990112304688, Generator Loss: -35.66407012939453
# (10, 91, 91, 146)
# Epoch: 54, Batch: 1, Critic Loss: -246.28038024902344, Generator Loss: -9.999313354492188
# (10, 91, 91, 146)
# Epoch: 54, Batch: 2, Critic Loss: -74.95700073242188, Generator Loss: 46.94762420654297
# (10, 91, 91, 146)
# Epoch: 54, Batch: 3, Critic Loss: -109.8775634765625, Generator Loss: 38.732215881347656
# (10, 91, 91, 146)
# Epoch: 54, Batch: 4, Critic Loss: -122.0644302368164, Generator Loss: 91.94340515136719
# (10, 91, 91, 146)
# Epoch: 54, Batch: 5, Critic Loss: -97.60454559326172, Generator Loss: -34.83649826049805
# (10, 91, 91, 146)
# Epoch: 55, Batch: 1, Critic Loss: -101.84123229980469, Generator Loss: -22.382038116455078
# (10, 91, 91, 146)
# Epoch: 55, Batch: 2, Critic Loss: -119.78817749023438, Generator Loss: -8.866032600402832
# (10, 91, 91, 146)
# Epoch: 55, Batch: 3, Critic Loss: -143.5936737060547, Generator Loss: -1.1671520471572876
# (10, 91, 91, 146)
# Epoch: 55, Batch: 4, Critic Loss: -164.701171875, Generator Loss: -26.6136474609375
# (10, 91, 91, 146)
# Epoch: 55, Batch: 5, Critic Loss: -208.4886016845703, Generator Loss: 21.951852798461914
# (10, 91, 91, 146)
# Epoch: 56, Batch: 1, Critic Loss: -100.03453063964844, Generator Loss: -3.147637128829956
# (10, 91, 91, 146)
# Epoch: 56, Batch: 2, Critic Loss: -117.5223388671875, Generator Loss: 18.983707427978516
# (10, 91, 91, 146)
# Epoch: 56, Batch: 3, Critic Loss: -118.8230972290039, Generator Loss: 38.86548614501953
# (10, 91, 91, 146)
# Epoch: 56, Batch: 4, Critic Loss: -162.77944946289062, Generator Loss: -21.43997573852539
# (10, 91, 91, 146)
# Epoch: 56, Batch: 5, Critic Loss: -203.0310821533203, Generator Loss: 25.690160751342773
# (10, 91, 91, 146)
# Epoch: 57, Batch: 1, Critic Loss: -136.72764587402344, Generator Loss: 33.74877166748047
# (10, 91, 91, 146)
# Epoch: 57, Batch: 2, Critic Loss: -83.96043395996094, Generator Loss: 80.01812744140625
# (10, 91, 91, 146)
# Epoch: 57, Batch: 3, Critic Loss: -288.2332763671875, Generator Loss: -24.646366119384766
# (10, 91, 91, 146)
# Epoch: 57, Batch: 4, Critic Loss: -153.1641845703125, Generator Loss: -33.75495147705078
# (10, 91, 91, 146)
# Epoch: 57, Batch: 5, Critic Loss: -84.03611755371094, Generator Loss: 24.25121307373047
# (10, 91, 91, 146)
# Epoch: 58, Batch: 1, Critic Loss: -99.18872833251953, Generator Loss: 16.62813949584961
# (10, 91, 91, 146)
# Epoch: 58, Batch: 2, Critic Loss: -182.0320587158203, Generator Loss: 29.43259048461914
# (10, 91, 91, 146)
# Epoch: 58, Batch: 3, Critic Loss: -161.93475341796875, Generator Loss: 80.96941375732422
# (10, 91, 91, 146)
# Epoch: 58, Batch: 4, Critic Loss: -72.58897399902344, Generator Loss: 2.0384182929992676
# (10, 91, 91, 146)
# Epoch: 58, Batch: 5, Critic Loss: -130.6143341064453, Generator Loss: -11.9932222366333
# (10, 91, 91, 146)
# Epoch: 59, Batch: 1, Critic Loss: -99.26777648925781, Generator Loss: -0.9937523007392883
# (10, 91, 91, 146)
# Epoch: 59, Batch: 2, Critic Loss: -143.71580505371094, Generator Loss: -15.615262031555176
# (10, 91, 91, 146)
# Epoch: 59, Batch: 3, Critic Loss: -134.44485473632812, Generator Loss: 44.5208625793457
# (10, 91, 91, 146)
# Epoch: 59, Batch: 4, Critic Loss: -164.35263061523438, Generator Loss: 11.713547706604004
# (10, 91, 91, 146)
# Epoch: 59, Batch: 5, Critic Loss: -184.81103515625, Generator Loss: 62.929969787597656
# (10, 91, 91, 146)
# Epoch: 60, Batch: 1, Critic Loss: -116.47190856933594, Generator Loss: 80.41596221923828
# (10, 91, 91, 146)
# Epoch: 60, Batch: 2, Critic Loss: -138.66725158691406, Generator Loss: 37.825687408447266
# (10, 91, 91, 146)
# Epoch: 60, Batch: 3, Critic Loss: -133.50694274902344, Generator Loss: 30.918590545654297
# (10, 91, 91, 146)
# Epoch: 60, Batch: 4, Critic Loss: -207.80613708496094, Generator Loss: -0.023137856274843216
# (10, 91, 91, 146)
# Epoch: 60, Batch: 5, Critic Loss: -115.92935180664062, Generator Loss: 48.173309326171875
# (10, 91, 91, 146)
# Epoch: 61, Batch: 1, Critic Loss: -168.02517700195312, Generator Loss: 71.54631042480469
# (10, 91, 91, 146)
# Epoch: 61, Batch: 2, Critic Loss: -179.73472595214844, Generator Loss: 67.45939636230469
# (10, 91, 91, 146)
# Epoch: 61, Batch: 3, Critic Loss: -146.7049102783203, Generator Loss: -84.07735443115234
# (10, 91, 91, 146)
# Epoch: 61, Batch: 4, Critic Loss: -119.98956298828125, Generator Loss: 27.725637435913086
# (10, 91, 91, 146)
# Epoch: 61, Batch: 5, Critic Loss: -106.1069107055664, Generator Loss: 91.97633361816406
# (10, 91, 91, 146)
# Epoch: 62, Batch: 1, Critic Loss: -111.4020767211914, Generator Loss: 76.86512756347656
# (10, 91, 91, 146)
# Epoch: 62, Batch: 2, Critic Loss: -160.79151916503906, Generator Loss: 94.45082092285156
# (10, 91, 91, 146)
# Epoch: 62, Batch: 3, Critic Loss: -142.63510131835938, Generator Loss: 89.83181762695312
# (10, 91, 91, 146)
# Epoch: 62, Batch: 4, Critic Loss: -108.01587677001953, Generator Loss: 76.40973663330078
# (10, 91, 91, 146)
# Epoch: 62, Batch: 5, Critic Loss: -121.08197021484375, Generator Loss: 54.7089958190918
# (10, 91, 91, 146)
# Epoch: 63, Batch: 1, Critic Loss: -146.9313507080078, Generator Loss: 65.87989807128906
# (10, 91, 91, 146)
# Epoch: 63, Batch: 2, Critic Loss: -129.44432067871094, Generator Loss: 73.35411071777344
# (10, 91, 91, 146)
# Epoch: 63, Batch: 3, Critic Loss: -128.27474975585938, Generator Loss: 117.62931060791016
# (10, 91, 91, 146)
# Epoch: 63, Batch: 4, Critic Loss: -134.23304748535156, Generator Loss: 26.095861434936523
# (10, 91, 91, 146)
# Epoch: 63, Batch: 5, Critic Loss: -110.80160522460938, Generator Loss: 28.946338653564453
# (10, 91, 91, 146)
# Epoch: 64, Batch: 1, Critic Loss: -104.3569107055664, Generator Loss: 55.28416061401367
# (10, 91, 91, 146)
# Epoch: 64, Batch: 2, Critic Loss: -172.23670959472656, Generator Loss: 27.665124893188477
# (10, 91, 91, 146)
# Epoch: 64, Batch: 3, Critic Loss: -150.77183532714844, Generator Loss: 81.5112533569336
# (10, 91, 91, 146)
# Epoch: 64, Batch: 4, Critic Loss: -146.80697631835938, Generator Loss: 18.84611701965332
# (10, 91, 91, 146)
# Epoch: 64, Batch: 5, Critic Loss: -122.7262191772461, Generator Loss: 32.312530517578125
# (10, 91, 91, 146)
# Epoch: 65, Batch: 1, Critic Loss: -161.35748291015625, Generator Loss: 30.469945907592773
# (10, 91, 91, 146)
# Epoch: 65, Batch: 2, Critic Loss: -131.85032653808594, Generator Loss: 75.84293365478516
# (10, 91, 91, 146)
# Epoch: 65, Batch: 3, Critic Loss: -78.83185577392578, Generator Loss: 75.95283508300781
# (10, 91, 91, 146)
# Epoch: 65, Batch: 4, Critic Loss: -111.74909973144531, Generator Loss: 138.73692321777344
# (10, 91, 91, 146)
# Epoch: 65, Batch: 5, Critic Loss: -178.7563934326172, Generator Loss: 149.77694702148438
# (10, 91, 91, 146)
# Epoch: 66, Batch: 1, Critic Loss: -113.03341674804688, Generator Loss: 168.96401977539062
# (10, 91, 91, 146)
# Epoch: 66, Batch: 2, Critic Loss: -147.608154296875, Generator Loss: 78.86551666259766
# (10, 91, 91, 146)
# Epoch: 66, Batch: 3, Critic Loss: -251.25921630859375, Generator Loss: 90.89466857910156
# (10, 91, 91, 146)
# Epoch: 66, Batch: 4, Critic Loss: -98.71826171875, Generator Loss: 65.18990325927734
# (10, 91, 91, 146)
# Epoch: 66, Batch: 5, Critic Loss: -122.0347671508789, Generator Loss: 88.36280822753906
# (10, 91, 91, 146)
# Epoch: 67, Batch: 1, Critic Loss: -114.531982421875, Generator Loss: 109.89176940917969
# (10, 91, 91, 146)
# Epoch: 67, Batch: 2, Critic Loss: -126.42278289794922, Generator Loss: 87.14826965332031
# (10, 91, 91, 146)
# Epoch: 67, Batch: 3, Critic Loss: -215.72274780273438, Generator Loss: 73.75457763671875
# (10, 91, 91, 146)
# Epoch: 67, Batch: 4, Critic Loss: -134.23068237304688, Generator Loss: 110.07868957519531
# (10, 91, 91, 146)
# Epoch: 67, Batch: 5, Critic Loss: -107.3582763671875, Generator Loss: 75.20411682128906
# (10, 91, 91, 146)
# Epoch: 68, Batch: 1, Critic Loss: -114.7333755493164, Generator Loss: 92.91081237792969
# (10, 91, 91, 146)
# Epoch: 68, Batch: 2, Critic Loss: -143.36062622070312, Generator Loss: 87.15595245361328
# (10, 91, 91, 146)
# Epoch: 68, Batch: 3, Critic Loss: -112.83345794677734, Generator Loss: 114.85627746582031
# (10, 91, 91, 146)
# Epoch: 68, Batch: 4, Critic Loss: -114.62094116210938, Generator Loss: 116.06941223144531
# (10, 91, 91, 146)
# Epoch: 68, Batch: 5, Critic Loss: -186.9837646484375, Generator Loss: 109.26060485839844
# (10, 91, 91, 146)
# Epoch: 69, Batch: 1, Critic Loss: -103.90118408203125, Generator Loss: 120.85734558105469
# (10, 91, 91, 146)
# Epoch: 69, Batch: 2, Critic Loss: -148.2259521484375, Generator Loss: 67.39962768554688
# (10, 91, 91, 146)
# Epoch: 69, Batch: 3, Critic Loss: -167.74807739257812, Generator Loss: 41.46216583251953
# (10, 91, 91, 146)
# Epoch: 69, Batch: 4, Critic Loss: -108.66554260253906, Generator Loss: 99.84619140625
# (10, 91, 91, 146)
# Epoch: 69, Batch: 5, Critic Loss: -115.19668579101562, Generator Loss: 132.62298583984375
# (10, 91, 91, 146)
# Epoch: 70, Batch: 1, Critic Loss: -109.80585479736328, Generator Loss: 104.77976989746094
# (10, 91, 91, 146)
# Epoch: 70, Batch: 2, Critic Loss: -146.59225463867188, Generator Loss: 32.893768310546875
# (10, 91, 91, 146)
# Epoch: 70, Batch: 3, Critic Loss: -101.61978149414062, Generator Loss: 118.98431396484375
# (10, 91, 91, 146)
# Epoch: 70, Batch: 4, Critic Loss: -148.39097595214844, Generator Loss: 118.24629974365234
# (10, 91, 91, 146)
# Epoch: 70, Batch: 5, Critic Loss: -200.7057647705078, Generator Loss: 103.25260162353516
# (10, 91, 91, 146)
# Epoch: 71, Batch: 1, Critic Loss: -147.15138244628906, Generator Loss: 86.01994323730469
# (10, 91, 91, 146)
# Epoch: 71, Batch: 2, Critic Loss: -107.01828002929688, Generator Loss: 127.60346984863281
# (10, 91, 91, 146)
# Epoch: 71, Batch: 3, Critic Loss: -129.0233917236328, Generator Loss: 136.10581970214844
# (10, 91, 91, 146)
# Epoch: 71, Batch: 4, Critic Loss: -113.45927429199219, Generator Loss: 146.5918731689453
# (10, 91, 91, 146)
# Epoch: 71, Batch: 5, Critic Loss: -198.52740478515625, Generator Loss: 180.858154296875
# (10, 91, 91, 146)
# Epoch: 72, Batch: 1, Critic Loss: -117.61991119384766, Generator Loss: 148.7454376220703
# (10, 91, 91, 146)
# Epoch: 72, Batch: 2, Critic Loss: -140.26406860351562, Generator Loss: 53.56188201904297
# (10, 91, 91, 146)
# Epoch: 72, Batch: 3, Critic Loss: -87.69451904296875, Generator Loss: 115.22868347167969
# (10, 91, 91, 146)
# Epoch: 72, Batch: 4, Critic Loss: -190.69837951660156, Generator Loss: 55.49938201904297
# (10, 91, 91, 146)
# Epoch: 72, Batch: 5, Critic Loss: -103.24423217773438, Generator Loss: 121.1064682006836
# (10, 91, 91, 146)
# Epoch: 73, Batch: 1, Critic Loss: -190.59835815429688, Generator Loss: 165.9123077392578
# (10, 91, 91, 146)
# Epoch: 73, Batch: 2, Critic Loss: -198.22499084472656, Generator Loss: 294.20904541015625
# (10, 91, 91, 146)
# Epoch: 73, Batch: 3, Critic Loss: -111.58618927001953, Generator Loss: 9.944220542907715
# (10, 91, 91, 146)
# Epoch: 73, Batch: 4, Critic Loss: -170.97291564941406, Generator Loss: 31.33950424194336
# (10, 91, 91, 146)
# Epoch: 73, Batch: 5, Critic Loss: -140.99603271484375, Generator Loss: 152.93089294433594
# (10, 91, 91, 146)
# Epoch: 74, Batch: 1, Critic Loss: -121.09635162353516, Generator Loss: 65.38865661621094
# (10, 91, 91, 146)
# Epoch: 74, Batch: 2, Critic Loss: -117.100830078125, Generator Loss: 113.2397232055664
# (10, 91, 91, 146)
# Epoch: 74, Batch: 3, Critic Loss: -131.2957763671875, Generator Loss: 136.7826690673828
# (10, 91, 91, 146)
# Epoch: 74, Batch: 4, Critic Loss: -127.61186981201172, Generator Loss: 137.04537963867188
# (10, 91, 91, 146)
# Epoch: 74, Batch: 5, Critic Loss: -160.63323974609375, Generator Loss: 129.1394500732422
# (10, 91, 91, 146)
# Epoch: 75, Batch: 1, Critic Loss: -128.95947265625, Generator Loss: 110.2238540649414
# (10, 91, 91, 146)
# Epoch: 75, Batch: 2, Critic Loss: -114.82588958740234, Generator Loss: 125.01606750488281
# (10, 91, 91, 146)
# Epoch: 75, Batch: 3, Critic Loss: -92.27262115478516, Generator Loss: 146.46078491210938
# (10, 91, 91, 146)
# Epoch: 75, Batch: 4, Critic Loss: -265.8147888183594, Generator Loss: 233.15576171875
# (10, 91, 91, 146)
# Epoch: 75, Batch: 5, Critic Loss: -156.34898376464844, Generator Loss: 90.6012954711914
# (10, 91, 91, 146)
# Epoch: 76, Batch: 1, Critic Loss: -139.84219360351562, Generator Loss: 154.1968536376953
# (10, 91, 91, 146)
# Epoch: 76, Batch: 2, Critic Loss: -105.4112319946289, Generator Loss: 159.27517700195312
# (10, 91, 91, 146)
# Epoch: 76, Batch: 3, Critic Loss: -131.04330444335938, Generator Loss: 130.0790252685547
# (10, 91, 91, 146)
# Epoch: 76, Batch: 4, Critic Loss: -149.81674194335938, Generator Loss: 91.3134994506836
# (10, 91, 91, 146)
# Epoch: 76, Batch: 5, Critic Loss: -125.38104248046875, Generator Loss: 16.572351455688477
# (10, 91, 91, 146)
# Epoch: 77, Batch: 1, Critic Loss: -117.0494384765625, Generator Loss: 66.96131896972656
# (10, 91, 91, 146)
# Epoch: 77, Batch: 2, Critic Loss: -219.0572509765625, Generator Loss: 45.37791061401367
# (10, 91, 91, 146)
# Epoch: 77, Batch: 3, Critic Loss: -98.26115417480469, Generator Loss: 156.6636962890625
# (10, 91, 91, 146)
# Epoch: 77, Batch: 4, Critic Loss: -115.90684509277344, Generator Loss: 136.15341186523438
# (10, 91, 91, 146)
# Epoch: 77, Batch: 5, Critic Loss: -113.27310180664062, Generator Loss: 180.09799194335938
# (10, 91, 91, 146)
# Epoch: 78, Batch: 1, Critic Loss: -122.44354248046875, Generator Loss: 198.628662109375
# (10, 91, 91, 146)
# Epoch: 78, Batch: 2, Critic Loss: -118.68511962890625, Generator Loss: 145.6279754638672
# (10, 91, 91, 146)
# Epoch: 78, Batch: 3, Critic Loss: -104.77244567871094, Generator Loss: 101.7002182006836
# (10, 91, 91, 146)
# Epoch: 78, Batch: 4, Critic Loss: -171.82534790039062, Generator Loss: 140.7586212158203
# (10, 91, 91, 146)
# Epoch: 78, Batch: 5, Critic Loss: -149.63699340820312, Generator Loss: 109.3219985961914
# (10, 91, 91, 146)
# Epoch: 79, Batch: 1, Critic Loss: -137.22665405273438, Generator Loss: 68.70736694335938
# (10, 91, 91, 146)
# Epoch: 79, Batch: 2, Critic Loss: -214.47247314453125, Generator Loss: 161.39480590820312
# (10, 91, 91, 146)
# Epoch: 79, Batch: 3, Critic Loss: -105.47578430175781, Generator Loss: 115.4365463256836
# (10, 91, 91, 146)
# Epoch: 79, Batch: 4, Critic Loss: -68.13402557373047, Generator Loss: 114.78034973144531
# (10, 91, 91, 146)
# Epoch: 79, Batch: 5, Critic Loss: -130.56649780273438, Generator Loss: 120.4935073852539
# (10, 91, 91, 146)
# Epoch: 80, Batch: 1, Critic Loss: -175.38861083984375, Generator Loss: 142.131103515625
# (10, 91, 91, 146)
# Epoch: 80, Batch: 2, Critic Loss: -99.65177154541016, Generator Loss: 131.85598754882812
# (10, 91, 91, 146)
# Epoch: 80, Batch: 3, Critic Loss: -154.91744995117188, Generator Loss: 139.22406005859375
# (10, 91, 91, 146)
# Epoch: 80, Batch: 4, Critic Loss: -92.59716033935547, Generator Loss: 114.33914947509766
# (10, 91, 91, 146)
# Epoch: 80, Batch: 5, Critic Loss: -160.62237548828125, Generator Loss: 122.064697265625
# (10, 91, 91, 146)
# Epoch: 81, Batch: 1, Critic Loss: -145.51426696777344, Generator Loss: 173.42303466796875
# (10, 91, 91, 146)
# Epoch: 81, Batch: 2, Critic Loss: -131.32150268554688, Generator Loss: 164.93682861328125
# (10, 91, 91, 146)
# Epoch: 81, Batch: 3, Critic Loss: -167.54901123046875, Generator Loss: 102.0638427734375
# (10, 91, 91, 146)
# Epoch: 81, Batch: 4, Critic Loss: -139.156982421875, Generator Loss: 123.7970199584961
# (10, 91, 91, 146)
# Epoch: 81, Batch: 5, Critic Loss: -113.86775207519531, Generator Loss: 125.93033599853516
# (10, 91, 91, 146)
# Epoch: 82, Batch: 1, Critic Loss: -107.3395004272461, Generator Loss: 91.62153625488281
# (10, 91, 91, 146)
# Epoch: 82, Batch: 2, Critic Loss: -200.30767822265625, Generator Loss: 174.12820434570312
# (10, 91, 91, 146)
# Epoch: 82, Batch: 3, Critic Loss: -101.75691986083984, Generator Loss: 136.80880737304688
# (10, 91, 91, 146)
# Epoch: 82, Batch: 4, Critic Loss: -129.38087463378906, Generator Loss: 134.51876831054688
# (10, 91, 91, 146)
# Epoch: 82, Batch: 5, Critic Loss: -117.36029052734375, Generator Loss: 133.72476196289062
# (10, 91, 91, 146)
# Epoch: 83, Batch: 1, Critic Loss: -128.98214721679688, Generator Loss: 47.41230010986328
# (10, 91, 91, 146)
# Epoch: 83, Batch: 2, Critic Loss: -126.16413116455078, Generator Loss: 120.17655944824219
# (10, 91, 91, 146)
# Epoch: 83, Batch: 3, Critic Loss: -110.07019805908203, Generator Loss: 110.80122375488281
# (10, 91, 91, 146)
# Epoch: 83, Batch: 4, Critic Loss: -121.78932189941406, Generator Loss: 126.0536117553711
# (10, 91, 91, 146)
# Epoch: 83, Batch: 5, Critic Loss: -181.02220153808594, Generator Loss: 141.86476135253906
# (10, 91, 91, 146)
# Epoch: 84, Batch: 1, Critic Loss: -116.4013671875, Generator Loss: 172.76792907714844
# (10, 91, 91, 146)
# Epoch: 84, Batch: 2, Critic Loss: -140.8077392578125, Generator Loss: 163.2168731689453
# (10, 91, 91, 146)
# Epoch: 84, Batch: 3, Critic Loss: -131.0966033935547, Generator Loss: 198.32131958007812
# (10, 91, 91, 146)
# Epoch: 84, Batch: 4, Critic Loss: -141.57754516601562, Generator Loss: 266.1009216308594
# (10, 91, 91, 146)
# Epoch: 84, Batch: 5, Critic Loss: -163.82333374023438, Generator Loss: 52.400672912597656
# (10, 91, 91, 146)
# Epoch: 85, Batch: 1, Critic Loss: -123.82594299316406, Generator Loss: 35.26744842529297
# (10, 91, 91, 146)
# Epoch: 85, Batch: 2, Critic Loss: -261.5608215332031, Generator Loss: 28.127826690673828
# (10, 91, 91, 146)
# Epoch: 85, Batch: 3, Critic Loss: -92.84590911865234, Generator Loss: -7.403719902038574
# (10, 91, 91, 146)
# Epoch: 85, Batch: 4, Critic Loss: -140.03717041015625, Generator Loss: 159.4975128173828
# (10, 91, 91, 146)
# Epoch: 85, Batch: 5, Critic Loss: -152.40463256835938, Generator Loss: 244.5403289794922
# (10, 91, 91, 146)
# Epoch: 86, Batch: 1, Critic Loss: -169.26516723632812, Generator Loss: 260.14727783203125
# (10, 91, 91, 146)
# Epoch: 86, Batch: 2, Critic Loss: -242.10736083984375, Generator Loss: 370.93060302734375
# (10, 91, 91, 146)
# Epoch: 86, Batch: 3, Critic Loss: -137.59815979003906, Generator Loss: 140.85792541503906
# (10, 91, 91, 146)
# Epoch: 86, Batch: 4, Critic Loss: -113.98885345458984, Generator Loss: 47.70702362060547
# (10, 91, 91, 146)
# Epoch: 86, Batch: 5, Critic Loss: -93.54572296142578, Generator Loss: -17.929140090942383
# (10, 91, 91, 146)
# Epoch: 87, Batch: 1, Critic Loss: -163.999267578125, Generator Loss: 251.2760467529297
# (10, 91, 91, 146)
# Epoch: 87, Batch: 2, Critic Loss: -126.23533630371094, Generator Loss: 251.5621795654297
# (10, 91, 91, 146)
# Epoch: 87, Batch: 3, Critic Loss: -163.81637573242188, Generator Loss: 29.501964569091797
# (10, 91, 91, 146)
# Epoch: 87, Batch: 4, Critic Loss: -107.20789337158203, Generator Loss: 93.20459747314453
# (10, 91, 91, 146)
# Epoch: 87, Batch: 5, Critic Loss: -153.0780792236328, Generator Loss: 46.969200134277344
# (10, 91, 91, 146)
# Epoch: 88, Batch: 1, Critic Loss: -165.3258056640625, Generator Loss: 90.6661605834961
# (10, 91, 91, 146)
# Epoch: 88, Batch: 2, Critic Loss: -161.3152313232422, Generator Loss: 54.254844665527344
# (10, 91, 91, 146)
# Epoch: 88, Batch: 3, Critic Loss: -99.71045684814453, Generator Loss: 167.81851196289062
# (10, 91, 91, 146)
# Epoch: 88, Batch: 4, Critic Loss: -137.59994506835938, Generator Loss: 178.7691192626953
# (10, 91, 91, 146)
# Epoch: 88, Batch: 5, Critic Loss: -113.75355529785156, Generator Loss: 180.20565795898438
# (10, 91, 91, 146)
# Epoch: 89, Batch: 1, Critic Loss: -160.04080200195312, Generator Loss: 240.34652709960938
# (10, 91, 91, 146)
# Epoch: 89, Batch: 2, Critic Loss: -173.4145050048828, Generator Loss: 183.07101440429688
# (10, 91, 91, 146)
# Epoch: 89, Batch: 3, Critic Loss: -136.10267639160156, Generator Loss: 166.23828125
# (10, 91, 91, 146)
# Epoch: 89, Batch: 4, Critic Loss: -134.52999877929688, Generator Loss: 201.8310546875
# (10, 91, 91, 146)
# Epoch: 89, Batch: 5, Critic Loss: -153.2681884765625, Generator Loss: 156.33238220214844
# (10, 91, 91, 146)
# Epoch: 90, Batch: 1, Critic Loss: -196.34759521484375, Generator Loss: 167.59523010253906
# (10, 91, 91, 146)
# Epoch: 90, Batch: 2, Critic Loss: -114.61154174804688, Generator Loss: 225.8226318359375
# (10, 91, 91, 146)
# Epoch: 90, Batch: 3, Critic Loss: -113.10774230957031, Generator Loss: 182.29055786132812
# (10, 91, 91, 146)
# Epoch: 90, Batch: 4, Critic Loss: -103.48538970947266, Generator Loss: 177.05120849609375
# (10, 91, 91, 146)
# Epoch: 90, Batch: 5, Critic Loss: -96.46890258789062, Generator Loss: 133.8865509033203
# (10, 91, 91, 146)
# Epoch: 91, Batch: 1, Critic Loss: -136.97586059570312, Generator Loss: 159.74388122558594
# (10, 91, 91, 146)
# Epoch: 91, Batch: 2, Critic Loss: -109.52072143554688, Generator Loss: 192.7024688720703
# (10, 91, 91, 146)
# Epoch: 91, Batch: 3, Critic Loss: -178.24305725097656, Generator Loss: 180.1186065673828
# (10, 91, 91, 146)
# Epoch: 91, Batch: 4, Critic Loss: -113.36560821533203, Generator Loss: 220.736572265625
# (10, 91, 91, 146)
# Epoch: 91, Batch: 5, Critic Loss: -117.86427307128906, Generator Loss: 130.81338500976562
# (10, 91, 91, 146)
# Epoch: 92, Batch: 1, Critic Loss: -95.65048217773438, Generator Loss: 87.99030303955078
# (10, 91, 91, 146)
# Epoch: 92, Batch: 2, Critic Loss: -114.79850006103516, Generator Loss: 155.18484497070312
# (10, 91, 91, 146)
# Epoch: 92, Batch: 3, Critic Loss: -151.02447509765625, Generator Loss: 189.64199829101562
# (10, 91, 91, 146)
# Epoch: 92, Batch: 4, Critic Loss: -126.66462707519531, Generator Loss: 181.02012634277344
# (10, 91, 91, 146)
# Epoch: 92, Batch: 5, Critic Loss: -166.0203399658203, Generator Loss: 237.83349609375
# (10, 91, 91, 146)
# Epoch: 93, Batch: 1, Critic Loss: -81.91831970214844, Generator Loss: 275.3817443847656
# (10, 91, 91, 146)
# Epoch: 93, Batch: 2, Critic Loss: -184.283935546875, Generator Loss: 112.8246078491211
# (10, 91, 91, 146)
# Epoch: 93, Batch: 3, Critic Loss: -172.97097778320312, Generator Loss: 204.84375
# (10, 91, 91, 146)
# Epoch: 93, Batch: 4, Critic Loss: -113.83694458007812, Generator Loss: 242.4901885986328
# (10, 91, 91, 146)
# Epoch: 93, Batch: 5, Critic Loss: -95.51644897460938, Generator Loss: 257.5582580566406
# (10, 91, 91, 146)
# Epoch: 94, Batch: 1, Critic Loss: -178.43927001953125, Generator Loss: 173.9432373046875
# (10, 91, 91, 146)
# Epoch: 94, Batch: 2, Critic Loss: -152.98973083496094, Generator Loss: 188.45912170410156
# (10, 91, 91, 146)
# Epoch: 94, Batch: 3, Critic Loss: -151.7783966064453, Generator Loss: 261.22869873046875
# (10, 91, 91, 146)
# Epoch: 94, Batch: 4, Critic Loss: -120.60115051269531, Generator Loss: 141.17324829101562
# (10, 91, 91, 146)
# Epoch: 94, Batch: 5, Critic Loss: -122.2144775390625, Generator Loss: 160.4676971435547
# (10, 91, 91, 146)
# Epoch: 95, Batch: 1, Critic Loss: -117.21699523925781, Generator Loss: 183.85244750976562
# (10, 91, 91, 146)
# Epoch: 95, Batch: 2, Critic Loss: -122.28595733642578, Generator Loss: 174.13137817382812
# (10, 91, 91, 146)
# Epoch: 95, Batch: 3, Critic Loss: -111.540283203125, Generator Loss: 179.36868286132812
# (10, 91, 91, 146)
# Epoch: 95, Batch: 4, Critic Loss: -214.83062744140625, Generator Loss: 167.9684295654297
# (10, 91, 91, 146)
# Epoch: 95, Batch: 5, Critic Loss: -71.09423828125, Generator Loss: 180.7928924560547
# (10, 91, 91, 146)
# Epoch: 96, Batch: 1, Critic Loss: -132.62307739257812, Generator Loss: 190.3673858642578
# (10, 91, 91, 146)
# Epoch: 96, Batch: 2, Critic Loss: -125.64328002929688, Generator Loss: 194.34793090820312
# (10, 91, 91, 146)
# Epoch: 96, Batch: 3, Critic Loss: -154.53421020507812, Generator Loss: 182.976318359375
# (10, 91, 91, 146)
# Epoch: 96, Batch: 4, Critic Loss: -135.82472229003906, Generator Loss: 171.42086791992188
# (10, 91, 91, 146)
# Epoch: 96, Batch: 5, Critic Loss: -145.44100952148438, Generator Loss: 151.86788940429688
# (10, 91, 91, 146)
# Epoch: 97, Batch: 1, Critic Loss: -142.07469177246094, Generator Loss: 171.2508087158203
# (10, 91, 91, 146)
# Epoch: 97, Batch: 2, Critic Loss: -68.83334350585938, Generator Loss: 232.57583618164062
# (10, 91, 91, 146)
# Epoch: 97, Batch: 3, Critic Loss: -114.18672943115234, Generator Loss: 230.36026000976562
# (10, 91, 91, 146)
# Epoch: 97, Batch: 4, Critic Loss: -113.60865783691406, Generator Loss: 226.3731689453125
# (10, 91, 91, 146)
# Epoch: 97, Batch: 5, Critic Loss: -185.3406982421875, Generator Loss: 213.8956298828125
# (10, 91, 91, 146)
# Epoch: 98, Batch: 1, Critic Loss: -125.76834106445312, Generator Loss: 199.06283569335938
# (10, 91, 91, 146)
# Epoch: 98, Batch: 2, Critic Loss: -149.28082275390625, Generator Loss: 248.81884765625
# (10, 91, 91, 146)
# Epoch: 98, Batch: 3, Critic Loss: -129.604248046875, Generator Loss: 181.13601684570312
# (10, 91, 91, 146)
# Epoch: 98, Batch: 4, Critic Loss: -132.31137084960938, Generator Loss: 187.64952087402344
# (10, 91, 91, 146)
# Epoch: 98, Batch: 5, Critic Loss: -104.46846771240234, Generator Loss: 205.2635040283203
# (10, 91, 91, 146)
# Epoch: 99, Batch: 1, Critic Loss: -120.9046630859375, Generator Loss: 212.78518676757812
# (10, 91, 91, 146)
# Epoch: 99, Batch: 2, Critic Loss: -119.9872817993164, Generator Loss: 193.2097930908203
# (10, 91, 91, 146)
# Epoch: 99, Batch: 3, Critic Loss: -124.27111053466797, Generator Loss: 254.05563354492188
# (10, 91, 91, 146)
# Epoch: 99, Batch: 4, Critic Loss: -100.38316345214844, Generator Loss: 178.2039337158203
# (10, 91, 91, 146)
# Epoch: 99, Batch: 5, Critic Loss: -188.38294982910156, Generator Loss: 195.82089233398438
# Epoch 1/14
# 10/10 [==============================] - 1s 38ms/step - loss: 21.0794 - accuracy: 0.5532 - val_loss: 14.0799 - val_accuracy: 0.3333
# Epoch 2/14
# 10/10 [==============================] - 0s 16ms/step - loss: 17.0434 - accuracy: 0.5213 - val_loss: 7.7605 - val_accuracy: 0.3750
# Epoch 3/14
# 10/10 [==============================] - 0s 17ms/step - loss: 13.7522 - accuracy: 0.5319 - val_loss: 7.6812 - val_accuracy: 0.3750
# Epoch 4/14
# 10/10 [==============================] - 0s 17ms/step - loss: 14.6283 - accuracy: 0.4787 - val_loss: 8.2298 - val_accuracy: 0.3750
# Epoch 5/14
# 10/10 [==============================] - 0s 17ms/step - loss: 16.6212 - accuracy: 0.5106 - val_loss: 6.5746 - val_accuracy: 0.3750
# Epoch 6/14
# 10/10 [==============================] - 0s 15ms/step - loss: 12.8625 - accuracy: 0.5000 - val_loss: 6.1342 - val_accuracy: 0.3750
# Epoch 7/14
# 10/10 [==============================] - 0s 16ms/step - loss: 14.2499 - accuracy: 0.4574 - val_loss: 5.9110 - val_accuracy: 0.3750
# Epoch 8/14
# 10/10 [==============================] - 0s 17ms/step - loss: 12.7433 - accuracy: 0.5638 - val_loss: 5.2851 - val_accuracy: 0.4167
# Epoch 9/14
# 10/10 [==============================] - 0s 17ms/step - loss: 16.4103 - accuracy: 0.4255 - val_loss: 9.3625 - val_accuracy: 0.3333
# Epoch 10/14
# 10/10 [==============================] - 0s 17ms/step - loss: 16.5284 - accuracy: 0.4787 - val_loss: 10.3777 - val_accuracy: 0.3333
# Epoch 11/14
# 10/10 [==============================] - 0s 17ms/step - loss: 15.7185 - accuracy: 0.4362 - val_loss: 4.8879 - val_accuracy: 0.4167
# Epoch 12/14
# 10/10 [==============================] - 0s 18ms/step - loss: 15.8339 - accuracy: 0.4574 - val_loss: 4.8833 - val_accuracy: 0.5417
# Epoch 13/14
# 10/10 [==============================] - 0s 17ms/step - loss: 12.8802 - accuracy: 0.4574 - val_loss: 5.7406 - val_accuracy: 0.3750
# Epoch 14/14
# 10/10 [==============================] - 0s 18ms/step - loss: 11.1105 - accuracy: 0.5000 - val_loss: 6.8100 - val_accuracy: 0.4167
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 277ms/step
# Test Loss: 6.682586908340454, Test Accuracy: 1.0975000262260437
# Actual labels vs. Predicted labels:
# Image 1: Actual: 0, Predicted: 0
# Image 2: Actual: 0, Predicted: 0
# Image 3: Actual: 1, Predicted: 0
# Image 4: Actual: 0, Predicted: 0
# Image 5: Actual: 0, Predicted: 0
# Image 6: Actual: 1, Predicted: 0
# Image 7: Actual: 0, Predicted: 1
# Image 8: Actual: 0, Predicted: 0
# Image 9: Actual: 0, Predicted: 0
# Image 10: Actual: 1, Predicted: 0
# Image 11: Actual: 1, Predicted: 1
# Image 12: Actual: 1, Predicted: 1
# Image 13: Actual: 1, Predicted: 1
# Image 14: Actual: 0, Predicted: 0
# Image 15: Actual: 1, Predicted: 0
# Image 16: Actual: 1, Predicted: 0
# Image 17: Actual: 1, Predicted: 0
# Image 18: Actual: 0, Predicted: 0
#
# Average Test Loss over 1 iterations: 3.341293454170227
# Average Test Accuracy over 1 iterations: 0.5487500131130219

# %%
'''# Generate a single fake image
z = np.random.normal(0, 1, (1, z_dim))
generated_image = generator.predict(z)[0]  # [0] to get the single image from the batch

# Get a single real image from the dataset
real_images = next(iter(train_dataset))[0]  # Assuming the dataset yields only images

# Take the first real image from the batch for comparison
real_image = real_images[0]

# Plot the real and fake images side by side
plt.figure(figsize=(10, 5))

# Plot real image
plt.subplot(1, 2, 1)
plt.imshow(real_image[:, :, 10, 0])  # Adjust indexing and color map as needed
plt.title('Real Image')
plt.axis('off')

# Plot fake image
plt.subplot(1, 2, 2)
plt.imshow(generated_image[:, :, 10, 0])  # Adjust indexing and color map as needed
plt.title('Generated Image')
plt.axis('off')

plt.tight_layout()
plt.show() '''
# Out:
# "# Generate a single fake image\nz = np.random.normal(0, 1, (1, z_dim))\ngenerated_image = generator.predict(z)[0]  # [0] to get the single image from the batch\n\n# Get a single real image from the dataset\nreal_images = next(iter(train_dataset))[0]  # Assuming the dataset yields only images\n\n# Take the first real image from the batch for comparison\nreal_image = real_images[0]\n\n# Plot the real and fake images side by side\nplt.figure(figsize=(10, 5))\n\n# Plot real image\nplt.subplot(1, 2, 1)\nplt.imshow(real_image[:, :, 10, 0])  # Adjust indexing and color map as needed\nplt.title('Real Image')\nplt.axis('off')\n\n# Plot fake image\nplt.subplot(1, 2, 2)\nplt.imshow(generated_image[:, :, 10, 0])  # Adjust indexing and color map as needed\nplt.title('Generated Image')\nplt.axis('off')\n\nplt.tight_layout()\nplt.show() "

# %%
#generator.save('wgan_generator_model_v3.h5')
#critic.save('wgan_critic_model_v3.h5')
