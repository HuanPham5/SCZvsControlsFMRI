# %% [markdown]
# # RNN 4D - no collapsing

# %%
import nibabel as nib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import numpy as np
import glob
import nibabel as nib
import os
import matplotlib.pyplot as plt
import scipy.ndimage
import random
from tensorflow.keras.layers import Dropout, Dense, Reshape, Flatten, Conv3D, Conv3DTranspose, LeakyReLU, Input, Embedding, multiply, Concatenate
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam, RMSprop
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, Dropout, BatchNormalization, Bidirectional, AdditiveAttention, LayerNormalization
from functools import partial
from tensorflow.keras import models, layers
# Out:
# 2024-09-02 16:24:11.579093: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-02 16:24:11.605955: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-02 16:24:11.605972: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-02 16:24:11.606841: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-02 16:24:11.612047: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-02 16:24:12.130049: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
full_schizophrenia_ids = [
    'A00009280', 'A00028806', 'A00023132', 'A00014804', 'A00016859', 'A00021598', 'A00001181', 'A00023158',
    'A00024568', 'A00028405', 'A00001251', 'A00000456', 'A00015648', 'A00002405', 'A00027391', 'A00016720',
    'A00018434', 'A00016197', 'A00027119', 'A00006754', 'A00009656', 'A00038441', 'A00012767', 'A00034273',
    'A00028404', 'A00035485', 'A00024684', 'A00018979', 'A00027537', 'A00004507', 'A00001452', 'A00023246',
    'A00027410', 'A00014719', 'A00024510', 'A00000368', 'A00019293', 'A00014830', 'A00015201', 'A00018403',
    'A00037854', 'A00024198', 'A00001243', 'A00014590', 'A00002337', 'A00024953', 'A00037224', 'A00027616',
    'A00001856', 'A00037619', 'A00024228', 'A00038624', 'A00037034', 'A00037649', 'A00022500', 'A00013216',
    'A00020787', 'A00028410', 'A00002480', 'A00028303', 'A00020602', 'A00024959', 'A00018598', 'A00014636',
    'A00019349', 'A00017147', 'A00023590', 'A00023750', 'A00031597', 'A00015518', 'A00018317', 'A00016723',
    'A00021591', 'A00023243', 'A00017943', 'A00023366', 'A00014607', 'A00020414', 'A00035003', 'A00028805',
    'A00029486', 'A00000541', 'A00028408', 'A00000909', 'A00031186', 'A00000838' ]

# schizohrenia_id that satisfy t>90, 59 in total
met_requirement_schizophrenia_ids = [
    'A00000368', 'A00000456', 'A00000541', 'A00000838', 'A00001251', 'A00001452', 'A00004507',
    'A00006754', 'A00009280', 'A00012767', 'A00013216', 'A00014607', 'A00014719', 'A00014804',
    'A00014830', 'A00015201', 'A00015648', 'A00016197', 'A00016720', 'A00016723', 'A00017147',
    'A00018317', 'A00018403', 'A00018434', 'A00018979', 'A00019293', 'A00020414', 'A00020602', 
    'A00020787', 'A00021591', 'A00021598', 'A00023158', 'A00023246', 'A00023590', 'A00023750', 
    'A00024198', 'A00024228', 'A00024568', 'A00024684', 'A00024953', 'A00024959', 'A00027410', 
    'A00027537', 'A00028303', 'A00028404', 'A00028408', 'A00028805', 'A00028806', 'A00031186', 
    'A00031597', 'A00034273', 'A00035003', 'A00035485', 'A00037034', 'A00037224', 'A00037619', 
    'A00037649', 'A00038441', 'A00038624']

full_control_ids = [
    'A00007409', 'A00013140', 'A00021145', 'A00036049', 'A00022810', 'A00002198', 'A00020895', 'A00004667',
    'A00015826', 'A00023120', 'A00022837', 'A00010684', 'A00009946', 'A00037318', 'A00033214', 'A00022490',
    'A00023848', 'A00029452', 'A00037564', 'A00036555', 'A00023095', 'A00022729', 'A00024955', 'A00024160',
    'A00011725', 'A00027487', 'A00024446', 'A00014898', 'A00015759', 'A00028409', 'A00017294', 'A00014522',
    'A00012995', 'A00031764', 'A00025969', 'A00033147', 'A00018553', 'A00023143', 'A00036916', 'A00028052',
    'A00023337', 'A00023730', 'A00020805', 'A00020984', 'A00000300', 'A00010150', 'A00024932', 'A00035537',
    'A00022509', 'A00028406', 'A00004087', 'A00035751', 'A00023800', 'A00027787', 'A00022687', 'A00023866',
    'A00021085', 'A00022619', 'A00036897', 'A00019888', 'A00021058', 'A00022835', 'A00037495', 'A00026945',
    'A00018716', 'A00026907', 'A00023330', 'A00016199', 'A00037238', 'A00023131', 'A00014120', 'A00021072',
    'A00037665', 'A00022400', 'A00003150', 'A00024372', 'A00021081', 'A00022592', 'A00022653', 'A00013816',
    'A00014839', 'A00031478', 'A00014225', 'A00013363', 'A00037007', 'A00020968', 'A00024301', 'A00024820',
    'A00035469', 'A00029226', 'A00022915', 'A00022773', 'A00024663', 'A00036844', 'A00009207', 'A00024535',
    'A00022727', 'A00011265', 'A00024546'
]

 # 82 controls that met requirement
met_requirement_control_ids = [
    'A00000300', 'A00002198', 'A00003150', 'A00004087', 'A00007409', 'A00010684', 'A00011265', 'A00011725',
    'A00012995', 'A00013140', 'A00013816', 'A00014839', 'A00014898', 'A00015759', 'A00015826', 'A00018553',
    'A00018716', 'A00019888', 'A00020805', 'A00020895', 'A00020968', 'A00020984', 'A00021058', 'A00021072',
    'A00021081', 'A00021085', 'A00022400', 'A00022490', 'A00022509', 'A00022592', 'A00022619', 'A00022653',
    'A00022687', 'A00022727', 'A00022729', 'A00022773', 'A00022810', 'A00022835', 'A00022837', 'A00022915',
    'A00023095', 'A00023120', 'A00023131', 'A00023143', 'A00023330', 'A00023337', 'A00023730', 'A00023800',
    'A00023848', 'A00023866', 'A00024160', 'A00024301', 'A00024372', 'A00024446', 'A00024535', 'A00024546', 
    'A00024663', 'A00024820', 'A00024932', 'A00024955', 'A00025969', 'A00026945', 'A00027487', 'A00027787', 
    'A00028052', 'A00028406', 'A00028409', 'A00029226', 'A00029452', 'A00031478', 'A00031764', 'A00033214', 
    'A00035751', 'A00036049', 'A00036555', 'A00036844', 'A00037007', 'A00037238', 'A00037318', 'A00037495', 
    'A00037564', 'A00037665'
]

# %%
# GAN Training Data Selection
gan_train_ids_schiz = random.sample(met_requirement_schizophrenia_ids, 2)
gan_test_ids_schiz = [id for id in met_requirement_schizophrenia_ids if id not in gan_train_ids_schiz]

gan_train_ids_control = random.sample(met_requirement_control_ids, 2)
gan_test_ids_control = [id for id in met_requirement_control_ids if id not in gan_train_ids_control]
gan_test_ids_control = random.sample(gan_test_ids_control,2)

''' data training for classifier '''
''' just use the same train set as GAN above '''

# Classifier Test Data Selection
classifier_test_ids = gan_test_ids_schiz + gan_test_ids_control

''' File loading '''
# Specify the directory and file pattern
directory_path = '../4D/'
file_pattern = 'A*_????_func_FL_FD_RPI_DSP_MCF_SS_SM_Nui_CS_InStandard.nii.gz'

# Construct the full path pattern
path_pattern = f'{directory_path}/{file_pattern}'

# Use glob to find all matching files
matching_files = glob.glob(path_pattern)

''' File loading for GAN Training and classifer '''
''' But this time we have 2 separate GANs, 1 train on schizoprenia and 1 train on control'''

#classifier_image_data = []
#classifier_labels = []  # 1 for schizophrenia, 0 for non-schizophrenia
gan_image_data_schiz = []
gan_image_data_control = []

for file_path in matching_files:
    filename = os.path.basename(file_path)
    file_id = filename.split('_')[0]
    
    if file_id in gan_train_ids_schiz:
        t1_img = nib.load(file_path)
        t1_data = t1_img.get_fdata()
        

        if t1_data.shape[3] < 90:
            continue

        #t1_data = np.sum(t1_data, axis=1)
        print('shape of image: ', t1_data.shape)
        gan_image_data_schiz.append(t1_data)

    if file_id in gan_train_ids_control:
        t1_img = nib.load(file_path)
        t1_data = t1_img.get_fdata()

        if t1_data.shape[3] < 90:
            continue

        #t1_data = np.sum(t1_data, axis=1)
        gan_image_data_control.append(t1_data)


print(f"Total GAN control loaded: {len(gan_image_data_control)}")
print(f"Total GAN schiz loaded: {len(gan_image_data_schiz)}")



'''Determine the maximum time-dimension size '''
max_z_size_schiz = max(img.shape[3] for img in gan_image_data_schiz)
max_z_size_control = max(img.shape[3] for img in gan_image_data_control)
max_t_size = max(max_z_size_schiz,max_z_size_control)


# Normalize and pad the data
def normalize_and_pad(data, max_t):
    normalized = (data - np.min(data)) / (np.max(data) - np.min(data)) * 2 - 1
    padded = np.pad(normalized, ((0, 0), (0, 0), (0, 0), (0, max_t - data.shape[3])), mode='constant')
    return padded

padded_data_schiz = [normalize_and_pad(img, max_t_size) for img in gan_image_data_schiz]
padded_data_control = [normalize_and_pad(img, max_t_size) for img in gan_image_data_control]

# Convert to numpy arrays and add dummy channel dimension
padded_data_array_schiz = np.expand_dims(np.array(padded_data_schiz), axis=-1)  # Shape: (n_samples, x, y, z, t, 1)
padded_data_array_control = np.expand_dims(np.array(padded_data_control), axis=-1)  # Shape: (n_samples, x, y, z, t, 1)

# Prepare datasets for TensorFlow
batch_size = 1
# train_dataset_schiz = tf.data.Dataset.from_tensor_slices((padded_data_array_schiz)).shuffle(len(padded_data_array_schiz)).batch(batch_size)
# train_dataset_control = tf.data.Dataset.from_tensor_slices((padded_data_array_control)).shuffle(len(padded_data_array_control)).batch(batch_size)
# Out:
# shape of image:  (91, 109, 91, 144)
# shape of image:  (91, 109, 91, 139)
# Total GAN control loaded: 2
# Total GAN schiz loaded: 2

# %%
# No need to reshape or flatten the data, as we're using 4D data directly
# train_images_schiz and train_images_control are already in the correct shape:
# (n_samples, x, y, z, t, 1)

# Create labels
labels_schiz = np.ones(len(padded_data_array_schiz))
labels_control = np.zeros(len(padded_data_array_control))

# Combine the datasets
train_images = np.concatenate((padded_data_array_schiz, padded_data_array_control), axis=0)
train_labels = np.concatenate((labels_schiz, labels_control), axis=0)

# Shuffle the dataset
indices = np.arange(train_images.shape[0])
np.random.shuffle(indices)
train_images = train_images[indices]
train_labels = train_labels[indices]

# Create TensorFlow dataset
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)
# Out:
# 2024-09-02 16:24:28.099469: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45195 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:17:00.0, compute capability: 8.6

# %%
def build_rnn_model():
    # Input shape: (time_steps, x, y, z)
    input_shape = (max_t_size, 91, 109, 91)  # (t, x, y, z)

    # Adding a channel dimension to make it compatible with ConvLSTM3D, dummy channel
    input_shape = input_shape + (1,)  # (t, x, y, z, 1)
    
    model = models.Sequential()
    
    # ConvLSTM3D layers for feature extraction and sequence processing
    model.add(layers.ConvLSTM3D(filters=16, kernel_size=(3, 3, 3), activation='relu', input_shape=input_shape, return_sequences=True))
    model.add(layers.BatchNormalization())
    
    # model.add(layers.ConvLSTM3D(filters=32, kernel_size=(3, 3, 3), activation='relu', return_sequences=True))
    # model.add(layers.BatchNormalization())
    
    # model.add(layers.ConvLSTM3D(filters=32, kernel_size=(3, 3, 3), activation='relu'))
    # model.add(layers.BatchNormalization())
    
    # Flatten the output before the dense layer, not needed
    #model.add(layers.Flatten())
    
    # Dense output layer for binary classification
    model.add(layers.Dense(1, activation='sigmoid'))
    
    # Compile the model
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    return model
    
rnn_model = build_rnn_model()
rnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_lstm3d (ConvLSTM3D)    (None, 146, 89, 107, 89   29440
#                              , 16)
#
#  batch_normalization (Batch  (None, 146, 89, 107, 89   64
#  Normalization)              , 16)
#
#  dense (Dense)               (None, 146, 89, 107, 89   17
#                              , 1)
#
# =================================================================
# Total params: 29521 (115.32 KB)
# Trainable params: 29489 (115.19 KB)
# Non-trainable params: 32 (128.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.mixed_precision import set_global_policy

# Set mixed precision policy to reduce memory usage
set_global_policy('mixed_float16')

# Control GPU memory growth
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA RTX A6000, compute capability 8.6
# Physical devices cannot be modified after being initialized

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.BinaryAccuracy(name='train_accuracy')

# Define number of epochs
epochs = 15

# Training loop
for epoch in range(epochs):
    # Reset the metrics at the start of the next epoch
    train_loss.reset_states()
    train_accuracy.reset_states()
    
    for images, labels in train_dataset:
        images = tf.transpose(images, perm=[0, 4, 1, 2, 3, 5])  # (batch, t, x, y, z, channels)
        
        with tf.GradientTape() as tape:
            predictions = rnn_model(images, training=True)
            loss = tf.keras.losses.binary_crossentropy(labels, tf.squeeze(predictions, axis=1))
        
        gradients = tape.gradient(loss, rnn_model.trainable_variables)
        rnn_model.optimizer.apply_gradients(zip(gradients, rnn_model.trainable_variables))
        
        # Update the metrics
        train_loss.update_state(loss)
        train_accuracy.update_state(labels, tf.squeeze(predictions, axis=1))
    
    # Print the loss and accuracy for the current epoch
    print(f"Epoch {epoch + 1}, Loss: {train_loss.result().numpy()}, Training Accuracy: {train_accuracy.result().numpy()}")
# Out:
# 2024-09-02 16:24:32.598266: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-09-02 16:24:43.781195: W external/local_tsl/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.7KiB (rounded to 1792)requested by op Conv3D
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-09-02 16:24:43.781330: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-09-02 16:24:43.781354: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 33, Chunks in use: 33. 8.2KiB allocated for chunks. 8.2KiB in use in bin. 961B client-requested in use in bin.
# 2024-09-02 16:24:43.781370: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 1, Chunks in use: 0. 768B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-09-02 16:24:43.781388: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 109, Chunks in use: 109. 190.2KiB allocated for chunks. 190.2KiB in use in bin. 183.3KiB client-requested in use in bin.
# 2024-09-02 16:24:43.781399: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-09-02 16:24:43.781411: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 1, Chunks in use: 1. 6.8KiB allocated for chunks. 6.8KiB in use in bin. 6.8KiB client-requested in use in bin.
# 2024-09-02 16:24:43.781421: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-09-02 16:24:43.781434: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 108, Chunks in use: 108. 2.85MiB allocated for chunks. 2.85MiB in use in bin. 2.85MiB client-requested in use in bin.
# 2024-09-02 16:24:43.781444: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-09-02 16:24:43.781458: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 1, Chunks in use: 1. 108.0KiB allocated for chunks. 108.0KiB in use in bin. 108.0KiB client-requested in use in bin.
# 2024-09-02 16:24:43.781468: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-09-02 16:24:43.781478: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-09-02 16:24:43.781488: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-09-02 16:24:43.781499: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-09-02 16:24:43.781513: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 146, Chunks in use: 146. 502.73MiB allocated for chunks. 502.73MiB in use in bin. 502.71MiB client-requested in use in bin.
# 2024-09-02 16:24:43.781525: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 1, Chunks in use: 1. 6.79MiB allocated for chunks. 6.79MiB in use in bin. 3.44MiB client-requested in use in bin.
# 2024-09-02 16:24:43.781535: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-09-02 16:24:43.781545: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-09-02 16:24:43.781558: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 755, Chunks in use: 755. 38.14GiB allocated for chunks. 38.14GiB in use in bin. 38.14GiB client-requested in use in bin.
# 2024-09-02 16:24:43.781571: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 1, Chunks in use: 1. 96.95MiB allocated for chunks. 96.95MiB in use in bin. 51.73MiB client-requested in use in bin.
# 2024-09-02 16:24:43.781586: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-09-02 16:24:43.781598: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 3, Chunks in use: 3. 5.40GiB allocated for chunks. 5.40GiB in use in bin. 5.40GiB client-requested in use in bin.
# 2024-09-02 16:24:43.781610: I external/local_tsl/tsl/framework/bfc_allocator.cc:1062] Bin for 1.8KiB was 1.0KiB, Chunk State:
# 2024-09-02 16:24:43.781619: I external/local_tsl/tsl/framework/bfc_allocator.cc:1075] Next region of size 47391244288
# 2024-09-02 16:24:43.781634: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f88ee000000 of size 4217082880 next 1
# 2024-09-02 16:24:43.781643: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95b9400 of size 1280 next 2
# 2024-09-02 16:24:43.781652: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95b9900 of size 256 next 3
# 2024-09-02 16:24:43.781661: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95b9a00 of size 256 next 4
# 2024-09-02 16:24:43.781669: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95b9b00 of size 256 next 5
# 2024-09-02 16:24:43.781677: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95b9c00 of size 256 next 6
# 2024-09-02 16:24:43.781685: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95b9d00 of size 256 next 7
# 2024-09-02 16:24:43.781692: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95b9e00 of size 256 next 8
# 2024-09-02 16:24:43.781700: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95b9f00 of size 256 next 9
# 2024-09-02 16:24:43.781708: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95ba000 of size 256 next 11
# 2024-09-02 16:24:43.781716: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95ba100 of size 256 next 12
# 2024-09-02 16:24:43.781724: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95ba200 of size 256 next 13
# 2024-09-02 16:24:43.781732: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95ba300 of size 256 next 10
# 2024-09-02 16:24:43.781739: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95ba400 of size 256 next 18
# 2024-09-02 16:24:43.781747: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95ba500 of size 256 next 20
# 2024-09-02 16:24:43.781755: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95ba600 of size 256 next 17
# 2024-09-02 16:24:43.781763: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95ba700 of size 256 next 19
# 2024-09-02 16:24:43.781771: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95ba800 of size 256 next 21
# 2024-09-02 16:24:43.781779: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95ba900 of size 256 next 22
# 2024-09-02 16:24:43.781787: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95baa00 of size 256 next 23
# 2024-09-02 16:24:43.781795: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bab00 of size 256 next 25
# 2024-09-02 16:24:43.781802: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bac00 of size 256 next 24
# 2024-09-02 16:24:43.781810: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bad00 of size 256 next 26
# 2024-09-02 16:24:43.781818: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bae00 of size 256 next 27
# 2024-09-02 16:24:43.781826: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95baf00 of size 256 next 28
# 2024-09-02 16:24:43.781835: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bb000 of size 256 next 29
# 2024-09-02 16:24:43.781843: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bb100 of size 256 next 30
# 2024-09-02 16:24:43.781851: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bb200 of size 256 next 31
# 2024-09-02 16:24:43.781859: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bb300 of size 256 next 32
# 2024-09-02 16:24:43.781867: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bb400 of size 256 next 33
# 2024-09-02 16:24:43.781876: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bb500 of size 1792 next 184
# 2024-09-02 16:24:43.781884: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bbc00 of size 1792 next 185
# 2024-09-02 16:24:43.781892: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bc300 of size 1792 next 186
# 2024-09-02 16:24:43.781900: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bca00 of size 1792 next 187
# 2024-09-02 16:24:43.781908: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bd100 of size 256 next 1157
# 2024-09-02 16:24:43.781916: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bd200 of size 256 next 1158
# 2024-09-02 16:24:43.781924: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bd300 of size 256 next 194
# 2024-09-02 16:24:43.781932: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bd400 of size 256 next 204
# 2024-09-02 16:24:43.781940: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bd500 of size 256 next 205
# 2024-09-02 16:24:43.781948: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] Free  at 7f89e95bd600 of size 768 next 14
# 2024-09-02 16:24:43.781957: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bd900 of size 6912 next 15
# 2024-09-02 16:24:43.781966: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95bf400 of size 110592 next 16
# 2024-09-02 16:24:43.781975: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f89e95da400 of size 527135488 next 36
# 2024-09-02 16:24:43.781983: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a08c91700 of size 3610624 next 38
# 2024-09-02 16:24:43.781992: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a09002f00 of size 54243072 next 39
# 2024-09-02 16:24:43.782001: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0c3bde00 of size 3610624 next 37
# 2024-09-02 16:24:43.782008: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0c72f600 of size 3610624 next 40
# 2024-09-02 16:24:43.782016: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0caa0e00 of size 3610624 next 41
# 2024-09-02 16:24:43.782024: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0ce12600 of size 3610624 next 42
# 2024-09-02 16:24:43.782032: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0d183e00 of size 3610624 next 43
# 2024-09-02 16:24:43.782040: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0d4f5600 of size 3610624 next 44
# 2024-09-02 16:24:43.782048: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0d866e00 of size 3610624 next 45
# 2024-09-02 16:24:43.782056: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0dbd8600 of size 3610624 next 46
# 2024-09-02 16:24:43.782063: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0df49e00 of size 3610624 next 47
# 2024-09-02 16:24:43.782071: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0e2bb600 of size 3610624 next 48
# 2024-09-02 16:24:43.782079: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0e62ce00 of size 3610624 next 49
# 2024-09-02 16:24:43.782089: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0e99e600 of size 3610624 next 50
# 2024-09-02 16:24:43.782096: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0ed0fe00 of size 3610624 next 51
# 2024-09-02 16:24:43.782104: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0f081600 of size 3610624 next 52
# 2024-09-02 16:24:43.782112: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0f3f2e00 of size 3610624 next 53
# 2024-09-02 16:24:43.782120: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0f764600 of size 3610624 next 54
# 2024-09-02 16:24:43.782128: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0fad5e00 of size 3610624 next 55
# 2024-09-02 16:24:43.782136: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a0fe47600 of size 3610624 next 56
# 2024-09-02 16:24:43.782144: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a101b8e00 of size 3610624 next 57
# 2024-09-02 16:24:43.782151: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1052a600 of size 3610624 next 58
# 2024-09-02 16:24:43.782159: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1089be00 of size 3610624 next 59
# 2024-09-02 16:24:43.782167: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a10c0d600 of size 3610624 next 60
# 2024-09-02 16:24:43.782175: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a10f7ee00 of size 3610624 next 61
# 2024-09-02 16:24:43.782183: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a112f0600 of size 3610624 next 62
# 2024-09-02 16:24:43.782191: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a11661e00 of size 3610624 next 63
# 2024-09-02 16:24:43.782199: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a119d3600 of size 3610624 next 64
# 2024-09-02 16:24:43.782206: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a11d44e00 of size 3610624 next 65
# 2024-09-02 16:24:43.782214: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a120b6600 of size 3610624 next 66
# 2024-09-02 16:24:43.782222: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a12427e00 of size 3610624 next 67
# 2024-09-02 16:24:43.782230: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a12799600 of size 3610624 next 68
# 2024-09-02 16:24:43.782238: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a12b0ae00 of size 3610624 next 69
# 2024-09-02 16:24:43.782246: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a12e7c600 of size 3610624 next 70
# 2024-09-02 16:24:43.782254: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a131ede00 of size 3610624 next 71
# 2024-09-02 16:24:43.782261: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1355f600 of size 3610624 next 72
# 2024-09-02 16:24:43.782269: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a138d0e00 of size 3610624 next 73
# 2024-09-02 16:24:43.782277: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a13c42600 of size 3610624 next 74
# 2024-09-02 16:24:43.782285: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a13fb3e00 of size 3610624 next 75
# 2024-09-02 16:24:43.782293: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a14325600 of size 3610624 next 76
# 2024-09-02 16:24:43.782301: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a14696e00 of size 3610624 next 77
# 2024-09-02 16:24:43.782309: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a14a08600 of size 3610624 next 78
# 2024-09-02 16:24:43.782317: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a14d79e00 of size 3610624 next 79
# 2024-09-02 16:24:43.782325: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a150eb600 of size 3610624 next 80
# 2024-09-02 16:24:43.782334: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1545ce00 of size 3610624 next 81
# 2024-09-02 16:24:43.782342: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a157ce600 of size 3610624 next 82
# 2024-09-02 16:24:43.782351: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a15b3fe00 of size 3610624 next 83
# 2024-09-02 16:24:43.782358: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a15eb1600 of size 3610624 next 84
# 2024-09-02 16:24:43.782366: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a16222e00 of size 3610624 next 85
# 2024-09-02 16:24:43.782375: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a16594600 of size 3610624 next 86
# 2024-09-02 16:24:43.782383: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a16905e00 of size 3610624 next 87
# 2024-09-02 16:24:43.782391: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a16c77600 of size 3610624 next 88
# 2024-09-02 16:24:43.782399: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a16fe8e00 of size 3610624 next 89
# 2024-09-02 16:24:43.782407: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1735a600 of size 3610624 next 90
# 2024-09-02 16:24:43.782415: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a176cbe00 of size 3610624 next 91
# 2024-09-02 16:24:43.782423: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a17a3d600 of size 3610624 next 92
# 2024-09-02 16:24:43.782431: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a17daee00 of size 3610624 next 93
# 2024-09-02 16:24:43.782439: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a18120600 of size 3610624 next 94
# 2024-09-02 16:24:43.782447: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a18491e00 of size 3610624 next 95
# 2024-09-02 16:24:43.782455: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a18803600 of size 3610624 next 96
# 2024-09-02 16:24:43.782463: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a18b74e00 of size 3610624 next 97
# 2024-09-02 16:24:43.782471: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a18ee6600 of size 3610624 next 98
# 2024-09-02 16:24:43.782479: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a19257e00 of size 3610624 next 99
# 2024-09-02 16:24:43.782488: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a195c9600 of size 3610624 next 100
# 2024-09-02 16:24:43.782496: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1993ae00 of size 3610624 next 101
# 2024-09-02 16:24:43.782505: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a19cac600 of size 3610624 next 102
# 2024-09-02 16:24:43.782509: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1a01de00 of size 3610624 next 103
# 2024-09-02 16:24:43.782513: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1a38f600 of size 3610624 next 104
# 2024-09-02 16:24:43.782517: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1a700e00 of size 3610624 next 105
# 2024-09-02 16:24:43.782520: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1aa72600 of size 3610624 next 106
# 2024-09-02 16:24:43.782525: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1ade3e00 of size 3610624 next 107
# 2024-09-02 16:24:43.782530: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1b155600 of size 3610624 next 108
# 2024-09-02 16:24:43.782533: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1b4c6e00 of size 3610624 next 109
# 2024-09-02 16:24:43.782537: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1b838600 of size 3610624 next 110
# 2024-09-02 16:24:43.782542: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1bba9e00 of size 3610624 next 111
# 2024-09-02 16:24:43.782546: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1bf1b600 of size 3610624 next 112
# 2024-09-02 16:24:43.782550: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1c28ce00 of size 3610624 next 113
# 2024-09-02 16:24:43.782554: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1c5fe600 of size 3610624 next 114
# 2024-09-02 16:24:43.782558: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1c96fe00 of size 3610624 next 115
# 2024-09-02 16:24:43.782562: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1cce1600 of size 3610624 next 116
# 2024-09-02 16:24:43.782566: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1d052e00 of size 3610624 next 117
# 2024-09-02 16:24:43.782570: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1d3c4600 of size 3610624 next 118
# 2024-09-02 16:24:43.782574: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1d735e00 of size 3610624 next 119
# 2024-09-02 16:24:43.782578: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1daa7600 of size 3610624 next 120
# 2024-09-02 16:24:43.782582: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1de18e00 of size 3610624 next 121
# 2024-09-02 16:24:43.782586: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1e18a600 of size 3610624 next 122
# 2024-09-02 16:24:43.782590: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1e4fbe00 of size 3610624 next 123
# 2024-09-02 16:24:43.782596: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1e86d600 of size 3610624 next 124
# 2024-09-02 16:24:43.782600: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1ebdee00 of size 3610624 next 125
# 2024-09-02 16:24:43.782604: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1ef50600 of size 3610624 next 126
# 2024-09-02 16:24:43.782608: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1f2c1e00 of size 3610624 next 127
# 2024-09-02 16:24:43.782612: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1f633600 of size 3610624 next 128
# 2024-09-02 16:24:43.782616: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1f9a4e00 of size 3610624 next 129
# 2024-09-02 16:24:43.782620: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a1fd16600 of size 3610624 next 130
# 2024-09-02 16:24:43.782624: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a20087e00 of size 3610624 next 131
# 2024-09-02 16:24:43.782628: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a203f9600 of size 3610624 next 132
# 2024-09-02 16:24:43.782632: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a2076ae00 of size 3610624 next 133
# 2024-09-02 16:24:43.782637: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a20adc600 of size 3610624 next 134
# 2024-09-02 16:24:43.782640: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a20e4de00 of size 3610624 next 135
# 2024-09-02 16:24:43.782645: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a211bf600 of size 3610624 next 136
# 2024-09-02 16:24:43.782648: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a21530e00 of size 3610624 next 137
# 2024-09-02 16:24:43.782652: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a218a2600 of size 3610624 next 138
# 2024-09-02 16:24:43.782658: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a21c13e00 of size 3610624 next 139
# 2024-09-02 16:24:43.782660: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a21f85600 of size 3610624 next 140
# 2024-09-02 16:24:43.782661: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a222f6e00 of size 3610624 next 141
# 2024-09-02 16:24:43.782663: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a22668600 of size 3610624 next 142
# 2024-09-02 16:24:43.782665: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a229d9e00 of size 3610624 next 143
# 2024-09-02 16:24:43.782668: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a22d4b600 of size 3610624 next 144
# 2024-09-02 16:24:43.782669: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a230bce00 of size 3610624 next 145
# 2024-09-02 16:24:43.782671: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a2342e600 of size 3610624 next 146
# 2024-09-02 16:24:43.782673: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a2379fe00 of size 3610624 next 147
# 2024-09-02 16:24:43.782675: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a23b11600 of size 3610624 next 148
# 2024-09-02 16:24:43.782678: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a23e82e00 of size 3610624 next 149
# 2024-09-02 16:24:43.782680: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a241f4600 of size 3610624 next 150
# 2024-09-02 16:24:43.782681: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a24565e00 of size 3610624 next 151
# 2024-09-02 16:24:43.782683: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a248d7600 of size 3610624 next 152
# 2024-09-02 16:24:43.782685: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a24c48e00 of size 3610624 next 153
# 2024-09-02 16:24:43.782686: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a24fba600 of size 3610624 next 154
# 2024-09-02 16:24:43.782688: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a2532be00 of size 3610624 next 155
# 2024-09-02 16:24:43.782690: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a2569d600 of size 3610624 next 156
# 2024-09-02 16:24:43.782692: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a25a0ee00 of size 3610624 next 157
# 2024-09-02 16:24:43.782694: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a25d80600 of size 3610624 next 158
# 2024-09-02 16:24:43.782695: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a260f1e00 of size 3610624 next 159
# 2024-09-02 16:24:43.782697: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a26463600 of size 3610624 next 160
# 2024-09-02 16:24:43.782699: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a267d4e00 of size 3610624 next 161
# 2024-09-02 16:24:43.782701: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a26b46600 of size 3610624 next 162
# 2024-09-02 16:24:43.782703: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a26eb7e00 of size 3610624 next 163
# 2024-09-02 16:24:43.782704: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a27229600 of size 3610624 next 164
# 2024-09-02 16:24:43.782706: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a2759ae00 of size 3610624 next 165
# 2024-09-02 16:24:43.782708: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a2790c600 of size 3610624 next 166
# 2024-09-02 16:24:43.782709: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a27c7de00 of size 7121664 next 34
# 2024-09-02 16:24:43.782713: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a28348900 of size 1054270720 next 35
# 2024-09-02 16:24:43.782715: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a670b6e00 of size 3610624 next 167
# 2024-09-02 16:24:43.782716: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a67428600 of size 3610624 next 168
# 2024-09-02 16:24:43.782729: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a67799e00 of size 3610624 next 169
# 2024-09-02 16:24:43.782731: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a67b0b600 of size 3610624 next 170
# 2024-09-02 16:24:43.782733: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a67e7ce00 of size 3610624 next 171
# 2024-09-02 16:24:43.782734: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a681ee600 of size 3610624 next 172
# 2024-09-02 16:24:43.782736: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a6855fe00 of size 3610624 next 173
# 2024-09-02 16:24:43.782737: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a688d1600 of size 3610624 next 174
# 2024-09-02 16:24:43.782739: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a68c42e00 of size 3610624 next 175
# 2024-09-02 16:24:43.782740: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a68fb4600 of size 3610624 next 176
# 2024-09-02 16:24:43.782742: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a69325e00 of size 3610624 next 177
# 2024-09-02 16:24:43.782743: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a69697600 of size 3610624 next 178
# 2024-09-02 16:24:43.782746: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a69a08e00 of size 3610624 next 179
# 2024-09-02 16:24:43.782748: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a69d7a600 of size 3610624 next 180
# 2024-09-02 16:24:43.782749: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a6a0ebe00 of size 3610624 next 181
# 2024-09-02 16:24:43.782751: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a6a45d600 of size 3610624 next 182
# 2024-09-02 16:24:43.782752: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a6a7cee00 of size 3610624 next 183
# 2024-09-02 16:24:43.782754: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a6ab40600 of size 27648 next 188
# 2024-09-02 16:24:43.782755: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a6ab47200 of size 27648 next 189
# 2024-09-02 16:24:43.782758: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a6ab4de00 of size 27648 next 190
# 2024-09-02 16:24:43.782760: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a6ab54a00 of size 27648 next 191
# 2024-09-02 16:24:43.782761: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a6ab5b600 of size 54243072 next 195
# 2024-09-02 16:24:43.782763: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a6df16500 of size 54243072 next 196
# 2024-09-02 16:24:43.782765: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a712d1400 of size 54243072 next 197
# 2024-09-02 16:24:43.782766: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a7468c300 of size 54243072 next 198
# 2024-09-02 16:24:43.782768: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a77a47200 of size 54243072 next 199
# 2024-09-02 16:24:43.782770: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a7ae02100 of size 54243072 next 200
# 2024-09-02 16:24:43.782772: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a7e1bd000 of size 54243072 next 201
# 2024-09-02 16:24:43.782773: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a81577f00 of size 54243072 next 202
# 2024-09-02 16:24:43.782776: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a84932e00 of size 54243072 next 203
# 2024-09-02 16:24:43.782778: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a87cedd00 of size 54243072 next 206
# 2024-09-02 16:24:43.782779: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a8b0a8c00 of size 54243072 next 207
# 2024-09-02 16:24:43.782783: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a8e463b00 of size 54243072 next 208
# 2024-09-02 16:24:43.782785: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a9181ea00 of size 54243072 next 209
# 2024-09-02 16:24:43.782786: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a94bd9900 of size 54243072 next 210
# 2024-09-02 16:24:43.782788: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a97f94800 of size 54243072 next 211
# 2024-09-02 16:24:43.782790: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a9b34f700 of size 54243072 next 212
# 2024-09-02 16:24:43.782792: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8a9e70a600 of size 54243072 next 213
# 2024-09-02 16:24:43.782794: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8aa1ac5500 of size 54243072 next 214
# 2024-09-02 16:24:43.782796: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8aa4e80400 of size 54243072 next 215
# 2024-09-02 16:24:43.782798: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8aa823b300 of size 54243072 next 216
# 2024-09-02 16:24:43.782799: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8aab5f6200 of size 54243072 next 217
# 2024-09-02 16:24:43.782801: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8aae9b1100 of size 54243072 next 218
# 2024-09-02 16:24:43.782802: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ab1d6c000 of size 54243072 next 219
# 2024-09-02 16:24:43.782807: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ab5126f00 of size 54243072 next 220
# 2024-09-02 16:24:43.782809: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ab84e1e00 of size 54243072 next 221
# 2024-09-02 16:24:43.782811: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8abb89cd00 of size 54243072 next 222
# 2024-09-02 16:24:43.782812: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8abec57c00 of size 54243072 next 223
# 2024-09-02 16:24:43.782814: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ac2012b00 of size 54243072 next 224
# 2024-09-02 16:24:43.782817: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ac53cda00 of size 54243072 next 225
# 2024-09-02 16:24:43.782819: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ac8788900 of size 1792 next 193
# 2024-09-02 16:24:43.782820: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ac8789000 of size 1792 next 192
# 2024-09-02 16:24:43.782822: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ac8789700 of size 1792 next 226
# 2024-09-02 16:24:43.782824: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ac8789e00 of size 1792 next 227
# 2024-09-02 16:24:43.782826: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ac878a500 of size 27648 next 228
# 2024-09-02 16:24:43.782828: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ac8791100 of size 27648 next 229
# 2024-09-02 16:24:43.782830: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ac8797d00 of size 27648 next 230
# 2024-09-02 16:24:43.782831: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ac879e900 of size 27648 next 231
# 2024-09-02 16:24:43.782833: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ac87a5500 of size 54243072 next 234
# 2024-09-02 16:24:43.782835: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8acbb60400 of size 54243072 next 235
# 2024-09-02 16:24:43.782837: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8acef1b300 of size 54243072 next 236
# 2024-09-02 16:24:43.782839: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ad22d6200 of size 54243072 next 237
# 2024-09-02 16:24:43.782840: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ad5691100 of size 54243072 next 238
# 2024-09-02 16:24:43.782842: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ad8a4c000 of size 54243072 next 239
# 2024-09-02 16:24:43.782845: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8adbe06f00 of size 54243072 next 240
# 2024-09-02 16:24:43.782846: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8adf1c1e00 of size 54243072 next 241
# 2024-09-02 16:24:43.782848: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ae257cd00 of size 54243072 next 242
# 2024-09-02 16:24:43.782850: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ae5937c00 of size 54243072 next 243
# 2024-09-02 16:24:43.782852: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ae8cf2b00 of size 54243072 next 244
# 2024-09-02 16:24:43.782853: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8aec0ada00 of size 54243072 next 245
# 2024-09-02 16:24:43.782855: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8aef468900 of size 54243072 next 246
# 2024-09-02 16:24:43.782859: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8af2823800 of size 54243072 next 247
# 2024-09-02 16:24:43.782860: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8af5bde700 of size 54243072 next 248
# 2024-09-02 16:24:43.782862: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8af8f99600 of size 54243072 next 249
# 2024-09-02 16:24:43.782864: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8afc354500 of size 54243072 next 250
# 2024-09-02 16:24:43.782865: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8aff70f400 of size 54243072 next 251
# 2024-09-02 16:24:43.782868: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b02aca300 of size 54243072 next 252
# 2024-09-02 16:24:43.782870: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b05e85200 of size 54243072 next 253
# 2024-09-02 16:24:43.782872: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b09240100 of size 54243072 next 254
# 2024-09-02 16:24:43.782874: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b0c5fb000 of size 54243072 next 255
# 2024-09-02 16:24:43.782875: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b0f9b5f00 of size 54243072 next 256
# 2024-09-02 16:24:43.782877: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b12d70e00 of size 54243072 next 257
# 2024-09-02 16:24:43.782880: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b1612bd00 of size 54243072 next 258
# 2024-09-02 16:24:43.782882: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b194e6c00 of size 54243072 next 259
# 2024-09-02 16:24:43.782883: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b1c8a1b00 of size 54243072 next 260
# 2024-09-02 16:24:43.782885: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b1fc5ca00 of size 54243072 next 261
# 2024-09-02 16:24:43.782887: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b23017900 of size 54243072 next 262
# 2024-09-02 16:24:43.782889: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b263d2800 of size 1792 next 233
# 2024-09-02 16:24:43.782890: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b263d2f00 of size 1792 next 232
# 2024-09-02 16:24:43.782892: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b263d3600 of size 1792 next 263
# 2024-09-02 16:24:43.782894: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b263d3d00 of size 1792 next 264
# 2024-09-02 16:24:43.782896: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b263d4400 of size 27648 next 265
# 2024-09-02 16:24:43.782898: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b263db000 of size 27648 next 266
# 2024-09-02 16:24:43.782899: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b263e1c00 of size 27648 next 267
# 2024-09-02 16:24:43.782901: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b263e8800 of size 27648 next 268
# 2024-09-02 16:24:43.782903: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b263ef400 of size 54243072 next 271
# 2024-09-02 16:24:43.782905: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b297aa300 of size 54243072 next 272
# 2024-09-02 16:24:43.782906: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b2cb65200 of size 54243072 next 273
# 2024-09-02 16:24:43.782908: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b2ff20100 of size 54243072 next 274
# 2024-09-02 16:24:43.782910: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b332db000 of size 54243072 next 275
# 2024-09-02 16:24:43.782912: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b36695f00 of size 54243072 next 276
# 2024-09-02 16:24:43.782913: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b39a50e00 of size 54243072 next 277
# 2024-09-02 16:24:43.782915: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b3ce0bd00 of size 54243072 next 278
# 2024-09-02 16:24:43.782917: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b401c6c00 of size 54243072 next 279
# 2024-09-02 16:24:43.782919: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b43581b00 of size 54243072 next 280
# 2024-09-02 16:24:43.782921: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b4693ca00 of size 54243072 next 281
# 2024-09-02 16:24:43.782922: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b49cf7900 of size 54243072 next 282
# 2024-09-02 16:24:43.782924: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b4d0b2800 of size 54243072 next 283
# 2024-09-02 16:24:43.782926: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b5046d700 of size 54243072 next 284
# 2024-09-02 16:24:43.782928: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b53828600 of size 54243072 next 285
# 2024-09-02 16:24:43.782930: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b56be3500 of size 54243072 next 286
# 2024-09-02 16:24:43.782931: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b59f9e400 of size 54243072 next 287
# 2024-09-02 16:24:43.782933: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b5d359300 of size 54243072 next 288
# 2024-09-02 16:24:43.782935: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b60714200 of size 54243072 next 289
# 2024-09-02 16:24:43.782936: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b63acf100 of size 54243072 next 290
# 2024-09-02 16:24:43.782938: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b66e8a000 of size 54243072 next 291
# 2024-09-02 16:24:43.782940: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b6a244f00 of size 54243072 next 292
# 2024-09-02 16:24:43.782942: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b6d5ffe00 of size 54243072 next 293
# 2024-09-02 16:24:43.782944: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b709bad00 of size 54243072 next 294
# 2024-09-02 16:24:43.782945: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b73d75c00 of size 54243072 next 295
# 2024-09-02 16:24:43.782947: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b77130b00 of size 54243072 next 296
# 2024-09-02 16:24:43.782949: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b7a4eba00 of size 54243072 next 297
# 2024-09-02 16:24:43.782951: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b7d8a6900 of size 54243072 next 298
# 2024-09-02 16:24:43.782952: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b80c61800 of size 54243072 next 299
# 2024-09-02 16:24:43.782954: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b8401c700 of size 1792 next 270
# 2024-09-02 16:24:43.782956: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b8401ce00 of size 1792 next 269
# 2024-09-02 16:24:43.782957: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b8401d500 of size 1792 next 300
# 2024-09-02 16:24:43.782960: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b8401dc00 of size 1792 next 301
# 2024-09-02 16:24:43.782961: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b8401e300 of size 27648 next 302
# 2024-09-02 16:24:43.782963: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b84024f00 of size 27648 next 303
# 2024-09-02 16:24:43.782965: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b8402bb00 of size 27648 next 304
# 2024-09-02 16:24:43.782966: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b84032700 of size 27648 next 305
# 2024-09-02 16:24:43.782968: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b84039300 of size 54243072 next 308
# 2024-09-02 16:24:43.782970: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b873f4200 of size 54243072 next 309
# 2024-09-02 16:24:43.782972: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b8a7af100 of size 54243072 next 310
# 2024-09-02 16:24:43.782973: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b8db6a000 of size 54243072 next 311
# 2024-09-02 16:24:43.782975: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b90f24f00 of size 54243072 next 312
# 2024-09-02 16:24:43.782977: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b942dfe00 of size 54243072 next 313
# 2024-09-02 16:24:43.782978: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b9769ad00 of size 54243072 next 314
# 2024-09-02 16:24:43.782981: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b9aa55c00 of size 54243072 next 315
# 2024-09-02 16:24:43.782983: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8b9de10b00 of size 54243072 next 316
# 2024-09-02 16:24:43.782984: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ba11cba00 of size 54243072 next 317
# 2024-09-02 16:24:43.782986: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ba4586900 of size 54243072 next 318
# 2024-09-02 16:24:43.782988: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8ba7941800 of size 54243072 next 319
# 2024-09-02 16:24:43.782991: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f8baacfc700 of size 54243072 next 320
# ...
# 2024-09-02 16:24:43.784540: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f933522e700 of size 1792 next 1078
# 2024-09-02 16:24:43.784544: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f933522ee00 of size 27648 next 1079
# 2024-09-02 16:24:43.784547: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9335235a00 of size 27648 next 1080
# 2024-09-02 16:24:43.784549: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f933523c600 of size 27648 next 1081
# 2024-09-02 16:24:43.784551: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9335243200 of size 27648 next 1082
# 2024-09-02 16:24:43.784554: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9335249e00 of size 54243072 next 1085
# 2024-09-02 16:24:43.784556: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9338604d00 of size 54243072 next 1086
# 2024-09-02 16:24:43.784558: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f933b9bfc00 of size 54243072 next 1087
# 2024-09-02 16:24:43.784560: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f933ed7ab00 of size 54243072 next 1088
# 2024-09-02 16:24:43.784562: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9342135a00 of size 54243072 next 1089
# 2024-09-02 16:24:43.784564: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93454f0900 of size 54243072 next 1090
# 2024-09-02 16:24:43.784568: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93488ab800 of size 54243072 next 1091
# 2024-09-02 16:24:43.784570: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f934bc66700 of size 54243072 next 1092
# 2024-09-02 16:24:43.784572: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f934f021600 of size 54243072 next 1093
# 2024-09-02 16:24:43.784574: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93523dc500 of size 54243072 next 1094
# 2024-09-02 16:24:43.784577: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9355797400 of size 54243072 next 1095
# 2024-09-02 16:24:43.784581: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9358b52300 of size 54243072 next 1096
# 2024-09-02 16:24:43.784584: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f935bf0d200 of size 54243072 next 1097
# 2024-09-02 16:24:43.784587: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f935f2c8100 of size 54243072 next 1098
# 2024-09-02 16:24:43.784590: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9362683000 of size 54243072 next 1099
# 2024-09-02 16:24:43.784592: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9365a3df00 of size 54243072 next 1100
# 2024-09-02 16:24:43.784594: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9368df8e00 of size 54243072 next 1101
# 2024-09-02 16:24:43.784596: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f936c1b3d00 of size 54243072 next 1102
# 2024-09-02 16:24:43.784598: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f936f56ec00 of size 54243072 next 1103
# 2024-09-02 16:24:43.784600: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9372929b00 of size 54243072 next 1104
# 2024-09-02 16:24:43.784602: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9375ce4a00 of size 54243072 next 1105
# 2024-09-02 16:24:43.784606: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f937909f900 of size 54243072 next 1106
# 2024-09-02 16:24:43.784609: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f937c45a800 of size 54243072 next 1107
# 2024-09-02 16:24:43.784612: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f937f815700 of size 54243072 next 1108
# 2024-09-02 16:24:43.784614: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9382bd0600 of size 54243072 next 1109
# 2024-09-02 16:24:43.784617: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9385f8b500 of size 54243072 next 1110
# 2024-09-02 16:24:43.784619: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9389346400 of size 54243072 next 1111
# 2024-09-02 16:24:43.784621: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f938c701300 of size 54243072 next 1112
# 2024-09-02 16:24:43.784623: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f938fabc200 of size 54243072 next 1113
# 2024-09-02 16:24:43.784626: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9392e77100 of size 1792 next 1084
# 2024-09-02 16:24:43.784629: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9392e77800 of size 1792 next 1083
# 2024-09-02 16:24:43.784631: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9392e77f00 of size 1792 next 1114
# 2024-09-02 16:24:43.784633: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9392e78600 of size 1792 next 1115
# 2024-09-02 16:24:43.784636: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9392e78d00 of size 27648 next 1116
# 2024-09-02 16:24:43.784639: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9392e7f900 of size 27648 next 1117
# 2024-09-02 16:24:43.784641: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9392e86500 of size 27648 next 1118
# 2024-09-02 16:24:43.784643: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9392e8d100 of size 27648 next 1119
# 2024-09-02 16:24:43.784646: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9392e93d00 of size 54243072 next 1122
# 2024-09-02 16:24:43.784649: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f939624ec00 of size 54243072 next 1123
# 2024-09-02 16:24:43.784653: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f9399609b00 of size 54243072 next 1124
# 2024-09-02 16:24:43.784655: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f939c9c4a00 of size 54243072 next 1125
# 2024-09-02 16:24:43.784659: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f939fd7f900 of size 54243072 next 1126
# 2024-09-02 16:24:43.784662: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93a313a800 of size 54243072 next 1127
# 2024-09-02 16:24:43.784664: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93a64f5700 of size 54243072 next 1128
# 2024-09-02 16:24:43.784666: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93a98b0600 of size 54243072 next 1129
# 2024-09-02 16:24:43.784668: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93acc6b500 of size 54243072 next 1130
# 2024-09-02 16:24:43.784671: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93b0026400 of size 54243072 next 1131
# 2024-09-02 16:24:43.784673: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93b33e1300 of size 54243072 next 1132
# 2024-09-02 16:24:43.784675: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93b679c200 of size 54243072 next 1133
# 2024-09-02 16:24:43.784677: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93b9b57100 of size 54243072 next 1134
# 2024-09-02 16:24:43.784680: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93bcf12000 of size 54243072 next 1135
# 2024-09-02 16:24:43.784684: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93c02ccf00 of size 54243072 next 1136
# 2024-09-02 16:24:43.784685: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93c3687e00 of size 54243072 next 1137
# 2024-09-02 16:24:43.784687: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93c6a42d00 of size 54243072 next 1138
# 2024-09-02 16:24:43.784689: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93c9dfdc00 of size 54243072 next 1139
# 2024-09-02 16:24:43.784691: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93cd1b8b00 of size 54243072 next 1140
# 2024-09-02 16:24:43.784694: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93d0573a00 of size 54243072 next 1141
# 2024-09-02 16:24:43.784697: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93d392e900 of size 54243072 next 1142
# 2024-09-02 16:24:43.784700: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93d6ce9800 of size 54243072 next 1143
# 2024-09-02 16:24:43.784703: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93da0a4700 of size 54243072 next 1144
# 2024-09-02 16:24:43.784707: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93dd45f600 of size 54243072 next 1145
# 2024-09-02 16:24:43.784709: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93e081a500 of size 54243072 next 1146
# 2024-09-02 16:24:43.784711: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93e3bd5400 of size 54243072 next 1147
# 2024-09-02 16:24:43.784713: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93e6f90300 of size 54243072 next 1148
# 2024-09-02 16:24:43.784715: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93ea34b200 of size 54243072 next 1149
# 2024-09-02 16:24:43.784718: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93ed706100 of size 54243072 next 1150
# 2024-09-02 16:24:43.784720: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93f0ac1000 of size 1792 next 1121
# 2024-09-02 16:24:43.784722: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93f0ac1700 of size 1792 next 1120
# 2024-09-02 16:24:43.784724: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93f0ac1e00 of size 1792 next 1151
# 2024-09-02 16:24:43.784726: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93f0ac2500 of size 1792 next 1152
# 2024-09-02 16:24:43.784729: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93f0ac2c00 of size 27648 next 1153
# 2024-09-02 16:24:43.784733: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93f0ac9800 of size 27648 next 1154
# 2024-09-02 16:24:43.784734: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93f0ad0400 of size 27648 next 1155
# 2024-09-02 16:24:43.784737: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93f0ad7000 of size 27648 next 1156
# 2024-09-02 16:24:43.784739: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f93f0addc00 of size 101655552 next 18446744073709551615
# 2024-09-02 16:24:43.784741: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100]      Summary of in-use Chunks by size:
# 2024-09-02 16:24:43.784746: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 33 Chunks of size 256 totalling 8.2KiB
# 2024-09-02 16:24:43.784748: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1280 totalling 1.2KiB
# 2024-09-02 16:24:43.784751: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 108 Chunks of size 1792 totalling 189.0KiB
# 2024-09-02 16:24:43.784754: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 6912 totalling 6.8KiB
# 2024-09-02 16:24:43.784756: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 108 Chunks of size 27648 totalling 2.85MiB
# 2024-09-02 16:24:43.784759: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 110592 totalling 108.0KiB
# 2024-09-02 16:24:43.784761: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 146 Chunks of size 3610624 totalling 502.73MiB
# 2024-09-02 16:24:43.784763: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 7121664 totalling 6.79MiB
# 2024-09-02 16:24:43.784766: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 755 Chunks of size 54243072 totalling 38.14GiB
# 2024-09-02 16:24:43.784768: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 101655552 totalling 96.95MiB
# 2024-09-02 16:24:43.784770: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 527135488 totalling 502.71MiB
# 2024-09-02 16:24:43.784773: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1054270720 totalling 1005.43MiB
# 2024-09-02 16:24:43.784776: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 4217082880 totalling 3.93GiB
# 2024-09-02 16:24:43.784779: I external/local_tsl/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 44.14GiB
# 2024-09-02 16:24:43.784783: I external/local_tsl/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 47391244288 memory_limit_: 47391244288 available bytes: 0 curr_region_allocation_bytes_: 94782488576
# 2024-09-02 16:24:43.784790: I external/local_tsl/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                     47391244288
# InUse:                     47391243520
# MaxInUse:                  47391243520
# NumAllocs:                        1993
# MaxAllocSize:               4217082880
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-09-02 16:24:43.784808: W external/local_tsl/tsl/framework/bfc_allocator.cc:497] ****************************************************************************************************
# 2024-09-02 16:24:43.784833: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at conv_ops_impl.h:1131 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[16,3,3,3,1] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[7], line 17
#      14 images = tf.transpose(images, perm=[0, 4, 1, 2, 3, 5])  # (batch, t, x, y, z, channels)
#      16 with tf.GradientTape() as tape:
# ---> 17     predictions = rnn_model(images, training=True)
#      18     loss = tf.keras.losses.binary_crossentropy(labels, tf.squeeze(predictions, axis=1))
#      20 gradients = tape.gradient(loss, rnn_model.trainable_variables)
#
# File ~/.local/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.local/lib/python3.11/site-packages/keras/src/backend.py:6512, in conv3d(x, kernel, strides, padding, data_format, dilation_rate)
#    6510 x, tf_data_format = _preprocess_conv3d_input(x, data_format)
#    6511 padding = _preprocess_padding(padding)
# -> 6512 x = tf.compat.v1.nn.convolution(
#    6513     input=x,
#    6514     filter=kernel,
#    6515     dilation_rate=dilation_rate,
#    6516     strides=strides,
#    6517     padding=padding,
#    6518     data_format=tf_data_format,
#    6519 )
#    6520 if data_format == "channels_first" and tf_data_format == "NDHWC":
#    6521     x = tf.compat.v1.transpose(x, (0, 4, 1, 2, 3))
#
# ResourceExhaustedError: Exception encountered when calling layer 'conv_lstm3d' (type ConvLSTM3D).
#
# {{function_node __wrapped__Conv3D_device_/job:localhost/replica:0/task:0/device:GPU:0}} OOM when allocating tensor with shape[16,3,3,3,1] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Conv3D] name:
#
# Call arguments received by layer 'conv_lstm3d' (type ConvLSTM3D):
#   • inputs=tf.Tensor(shape=(1, 146, 91, 109, 91, 1), dtype=float32)
#   • mask=None
#   • training=True
#   • initial_state=None

# %%
def resize_image(image, new_shape):
    factors = (
        new_shape[0] / image.shape[0],
        new_shape[1] / image.shape[1],
        new_shape[2] / image.shape[2]
    )
    return scipy.ndimage.zoom(image, factors, order=1)  # order=1 is bilinear interpolation


test_image_data = []
test_labels = []

test_ids = classifier_test_ids  # List of IDs to filter test data

for file_path in matching_files:
    filename = os.path.basename(file_path)
    file_id = filename.split('_')[0]
    
    if file_id in test_ids:
        t1_img = nib.load(file_path)
        t1_data = t1_img.get_fdata()

        if t1_data.shape[3] < 90:
            continue
        
        t1_data_collapsed = np.sum(t1_data, axis=1)  # Summing over one axis

        # Resize the collapsed data
        processed_image = resize_image(t1_data_collapsed, (91, 91, 146))

        # Normalize the processed image
        processed_image_normalized = (processed_image - np.min(processed_image)) / (np.max(processed_image) - np.min(processed_image)) * 2 - 1

        # Reshape for RNN input: Flatten each 91x91 image to a single vector and treat each as a timestep
        processed_image_flattened = np.reshape(processed_image_normalized, (146, 91*91))

        test_image_data.append(processed_image_flattened)
        label = 1 if file_id in met_requirement_schizophrenia_ids else 0
        test_labels.append(label)

# Convert to numpy arrays for easier handling in TensorFlow
test_images_array = np.array(test_image_data)
test_labels_array = np.array(test_labels)

# Create a TensorFlow dataset from the numpy arrays
test_dataset = tf.data.Dataset.from_tensor_slices((test_images_array, test_labels_array)).batch(batch_size)

# %%
# Evaluate the model
loss, accuracy = rnn_model.evaluate(test_dataset)
print(f"Test loss: {loss}, Test accuracy: {accuracy}")

# %%
# Predict the probabilities
predictions = rnn_model.predict(test_dataset)
# Convert probabilities to class labels
predicted_labels = (predictions > 0.5).astype(int)

# Assuming test_labels_array contains your actual labels
actual_labels = test_labels_array

# Now you might want to compare these predicted_labels with the actual labels (test_labels)
# to compute the confusion matrix, classification report, etc.
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(actual_labels, predicted_labels.flatten()))
print(classification_report(actual_labels, predicted_labels.flatten()))

# %%
for actual, predicted in zip(actual_labels, predicted_labels):
    print(f'Actual: {actual}, Predicted: {predicted}')
